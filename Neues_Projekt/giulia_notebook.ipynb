# %%
import pandas as pd
df = pd.read_csv('ad_df.csv')

df.head()
# Out:
#             brand commercial_number  BDM  \
# 0   LittleCaesars            AD0654  1.0
# 1  PersilProclean            AD0612  1.0
# 2            Fiji            AD0482  0.0
# 3      DisneyPlus            AD0758  0.0
# 4          ETRADE            AD0701  0.0
#
#                                           transcript  total_bdm_terms_pct  \
# 0  Delivery available from locations with online ...             5.263158
# 1  STAIN LAB WATER V I IN Original ITS MORE THAN ...            10.714286
# 2  EARTHS FINEST WATER EARTHS FINEST WATER FIJI W...             8.108108
# 3  LORI Disney Plus has the greatest movies and s...             3.750000
# 4  ft THIS MIGHT BE THE YEAR YOU FINALLY GET IN S...             2.500000
#
#          comparatives                      superlatives  \
# 0                  []  ['best', 'best', 'Best', 'best']
# 1  ['MORE', 'deeper']            ['deepest', 'deepest']
# 2                  []                        ['finest']
# ...
