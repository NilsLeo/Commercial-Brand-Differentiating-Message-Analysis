# %%
from dotenv import load_dotenv
import os
import pandas as pd
import cv2
from easyocr import Reader

# %%
# Initialisiere EasyOCR mit der gewünschten Sprache (in dem Fall Englisch)
reader = Reader(['en'], gpu=True)

# %% [markdown]
# # Create output list for individual adverts

# %%
# Definiere den Pfad zu deinem Zielordner
target_folder = "/home/giulia/Commercial-Brand-Differentiating-Message-Analysis/01_input_frames_all/2016/ADs_IG_2016/AD0417"

# %% [markdown]
# ### Methode 2: Wasserzeichen abdecken mit schwarzen Box

# %%
# Funktion: Wasserzeichen-Bereich abdecken
def cover_watermark(frame, x, y, w, h, method="black"):
    """
    Überdeckt den Wasserzeichen-Bereich in einem Bild.
    Args:
    - frame: Das Bild/Frame (numpy-Array)
    - x, y: Obere linke Ecke des Wasserzeichen-Bereichs
    - w, h: Breite und Höhe des Wasserzeichen-Bereichs
    - method: Methode zum Abdecken ("black" oder "blur")
    """
    roi = frame[y:y+h, x:x+w]
    if method == "black":
        # Füllt den Bereich mit Schwarz
        frame[y:y+h, x:x+w] = (0, 0, 0)
    elif method == "blur":
        # Wendet einen Weichzeichner auf den Bereich an
        frame[y:y+h, x:x+w] = cv2.GaussianBlur(roi, (15, 15), 0)
    return frame

# %% [markdown]
# neue procee

# %%
def process_frames_with_watermark_removal(frames, x, y, w, h, method="black"):
    """
    Entfernt Wasserzeichen und führt OCR auf allen Frames durch, gruppiert die Ergebnisse nach Frames.
    Args:
        frames (List[Dict]): Eine Liste von Dictionaries mit Frame-Pfad und Werbungsnamen.
        x, y (int): Obere linke Ecke des Wasserzeichen-Bereichs.
        w, h (int): Breite und Höhe des Wasserzeichen-Bereichs.
        method (str): Methode zum Abdecken des Wasserzeichens ("black" oder "blur").

    Returns:
        pd.DataFrame: Ein DataFrame mit den gruppierten OCR-Ergebnissen (Spalten: Frame, Recognized_Text).
    """
    results_list = []

    # Iteriere durch alle Frames
    for frame_info in frames:
        ad_name = frame_info["ad"]
        frame_path = frame_info["frame_path"]

        # Lade das Bild
        image = cv2.imread(frame_path)

        # Abdeckung des Wasserzeichens
        image = cover_watermark(image, x, y, w, h, method)

        # Perform text recognition with EasyOCR (nur auf das abgedeckte Bild)
        ocr_results = reader.readtext(image)

        # Ergebnisse speichern
        for (bbox, text, prob) in ocr_results:
            # Überprüfe, ob der Text gültig ist (nicht leer oder nur Sonderzeichen)
            if text and text.strip() and len(text.strip()) > 1:  # Sicherstellen, dass der Text sinnvoll ist
                results_list.append({
                    "Frame": os.path.basename(frame_path),  # Nur der Dateiname
                    "Recognized_Text": text.strip(),       # Direkter Text ohne zusätzliche Filterung
                })

    # Ergebnisse in DataFrame umwandeln
    results_df = pd.DataFrame(results_list)

    # Gruppiere die Ergebnisse nach Frames
    merged_results = (
        results_df.groupby("Frame")
        .agg({
            "Recognized_Text": lambda x: ", ".join(x),  # Kombiniere alle erkannten Texte pro Frame
        })
        .reset_index()
    )

    return merged_results

# %% [markdown]
# ### Ähnliche Frames Gruppieren, Duplikate entfernen

# %%
from collections import Counter
from rapidfuzz import fuzz
import enchant
from collections import Counter

# Enchant-Wörterbuch für Englisch
checker = enchant.Dict("en_US")
def count_correct_spelled_words(text):
    """Zählt, wie viele Wörter im Text laut Enchant korrekt geschrieben sind."""
    words = text.split()
    correct_count = 0
    for w in words:
        if checker.check(w):
            correct_count += 1
    return correct_count

# Funktion: Gruppiere Texte nach Ähnlichkeit und wähle den häufigsten
def remove_similar_texts(texts, threshold=60):
    text_groups = []
    # 1) Gruppiere nach Ähnlichkeit
    for text in texts:
        group_found = False
        for group in text_groups:
            if fuzz.ratio(text, group[0]) >= threshold:  # Überprüfe Ähnlichkeit
                group.append(text)
                group_found = True
                break
        if not group_found:
            text_groups.append([text])
    # 2) Wähle pro Gruppe den Text mit den meisten korrekt geschriebenen Wörtern
    #return [Counter(group).most_common(1)[0][0] for group in text_groups]
    best_texts = []
    for group in text_groups:
        # Für jeden Text in der Gruppe ermitteln wir die "Score" der korrekt geschriebenen Wörter
        best_text = max(group, key=lambda t: count_correct_spelled_words(t))
        best_texts.append(best_text)
    
    return best_texts


# Funktion: Sortiere die Frame-Spalte numerisch
def sort_frames(dataframe, frame_column="Frame"):
    """
    Sortiert die DataFrame basierend auf der AD-Nummer und der Frame-Nummer.
    Args:
        dataframe (pd.DataFrame): Die DataFrame mit der Frame-Spalte.
        frame_column (str): Der Name der Spalte, die sortiert werden soll.
    Returns:
        pd.DataFrame: Die sortierte DataFrame.
    """
    # Filtere Zeilen mit Texten, die weniger als 2 Zeichen haben
    dataframe = dataframe[dataframe["Recognized_Text"].str.len() >= 3].copy()

    # Konvertiere alle Werte der Spalte in Strings (falls nicht bereits)
    dataframe[frame_column] = dataframe[frame_column].astype(str)
    
    # Funktion zur Extraktion der AD-Nummer und der Frame-Nummer
    def extract_ad_and_frame(value):
        try:
            # Zerlege den Frame-Namen
            parts = value.split("_")
            # Extrahiere die Haupt-AD-Nummer
            ad_part = int(parts[0][2:])  # "AD0251" → 251
            # Extrahiere das Untersegment, wenn vorhanden
            sub_ad_part = int(parts[1]) if len(parts) > 2 and parts[1].isdigit() else 0
            # Extrahiere die Frame-Nummer
            frame_part = int(parts[2].split(".")[0])  # "Frame_250.png" → 250
            return (ad_part, sub_ad_part, frame_part)
        except (IndexError, ValueError):
            # Fehlerhafte Werte behalten die Haupt-AD-Nummer, aber kommen ans Ende innerhalb dieser Gruppe
            try:
                ad_part = int(value.split("_")[0][2:])  # Extrahiere nur die Haupt-AD-Nummer
                return (ad_part, float('inf'), float('inf'))
            except:
                # Wenn auch die Haupt-AD-Nummer nicht extrahiert werden kann, ans Ende schieben
                return (float('inf'), float('inf'), float('inf'))
    
    # Sortiere die DataFrame basierend auf AD-Nummer und Frame-Nummer
    dataframe = dataframe.sort_values(
        by=frame_column,
        key=lambda col: col.map(extract_ad_and_frame)
    )
    return dataframe

# Funktion: Erstelle die bereinigte Tabelle
def create_cleaned_dataframe(merged_results, ad_column="Frame", text_column="Recognized_Text", threshold=60):
    # Extrahiere den "Ad"-Namen aus den Frame-Namen
    merged_results["ad"] = merged_results[ad_column].apply(lambda x: x.split("_")[0])  
    # Gruppiere nach "ad" und bereinige Texte
    cleaned_data = []
    for ad, group in merged_results.groupby("ad"):
        unique_texts = remove_similar_texts(group[text_column].tolist(), threshold=threshold)
        unique_texts = [text for text in unique_texts if text.strip()]
        combined_text = "; ".join(unique_texts)  # Kombiniere die bereinigten Texte
        cleaned_data.append({"ad": ad, "recognized_text": combined_text})
    
    # Erstelle eine neue DataFrame
    cleaned_df = pd.DataFrame(cleaned_data)
    return cleaned_df

# %%
#cleaned_df.to_csv("cleaned_df_box.csv", index=False)

# %% [markdown]
# ### durchführen

# %%
import pandas as pd

# Datei laden
file_path = "final_zwischenergebnis.csv"  # Pfad zur CSV-Datei
data = pd.read_csv(file_path)
df = pd.DataFrame(data)
df
# Out:
#                        Frame                 Recognized_Text      ad
# 0      AD0252_Frame_1610.png                        Bravery:  AD0252
# 1      AD0252_Frame_1620.png                        Bravery:  AD0252
# 2      AD0252_Frame_1630.png                        Bravery:  AD0252
# 3      AD0252_Frame_1640.png  Bravery: It'5 what defines us.  AD0252
# 4      AD0252_Frame_1650.png  Bravery: It's what defines us.  AD0252
# ...                      ...                             ...     ...
# 23657   AD0801_Frame_610.png                              FN  AD0801
# 23658   AD0801_Frame_810.png                        Wea, ;om  AD0801
# 23659   AD0801_Frame_820.png                WeatherTeche_com  AD0801
# 23660   AD0801_Frame_830.png                WeatherTeche_com  AD0801
# 23661   AD0801_Frame_840.png                WeatherTeche_com  AD0801
#
# [23662 rows x 3 columns]

# %%
#1 sortieren
sorted_df = sort_frames(df,"Frame")
sorted_df
# Out:
#                       Frame  \
# 19     AD0252_Frame_730.png
# 20     AD0252_Frame_740.png
# 21     AD0252_Frame_750.png
# 22     AD0252_Frame_760.png
# 23     AD0252_Frame_770.png
# ...                     ...
# 23655  AD0801_Frame_520.png
# 23658  AD0801_Frame_810.png
# 23659  AD0801_Frame_820.png
# 23660  AD0801_Frame_830.png
# 23661  AD0801_Frame_840.png
#
#                                          Recognized_Text      ad
# 19     '903, Closed Course, obey speed ard traffic la...  AD0252
# 20     '3596, Closed course . Alays obey speed andd t...  AD0252
# 21     '3n, Closed course . Alays obey speed and traf...  AD0252
# 22     Closec course . Always obey speed and traffic ...  AD0252
# 23     Closec course . Alays obey speed and traffic |...  AD0252
# ...                                                  ...     ...
# 23655                                           n=, Weai  AD0801
# 23658                                           Wea, ;om  AD0801
# 23659                                   WeatherTeche_com  AD0801
# 23660                                   WeatherTeche_com  AD0801
# 23661                                   WeatherTeche_com  AD0801
#
# [22644 rows x 3 columns]

# %%
#2 
zwischenergebnis = create_cleaned_dataframe(sorted_df,text_column="Recognized_Text", threshold=50)
zwischenergebnis
zwischenergebnis.to_csv("test_zwischen.csv", index=False)

# %% [markdown]
# # Main Script

# %%
def load_all_frames(input_folder):
    """
    Listet alle Frames aus allen Unterordnern auf.
    Args:
        input_folder (str): Der Pfad zum Hauptordner mit den Frames.
    Returns:
        List[Dict]: Eine Liste von Dictionaries mit Frame-Pfad und zugehörigem Werbungsnamen.
    """
    frames = []
    for root, dirs, files in os.walk(input_folder):
        for file in files:
            if file.endswith((".png", ".jpg")):  # Akzeptiere nur Bilddateien
                ad_name = os.path.basename(root)  # Name des Werbungs-Ordners
                frame_path = os.path.join(root, file)
                frames.append({"ad": ad_name, "frame_path": frame_path})
    return frames

# %%
def process_all_ads(input_folder, x=62, y=545, w=235, h=60, method="black", threshold=70):
    """
    Hauptpipeline, die alle Schritte für die Verarbeitung aller Werbungen durchführt.
    Args:
        input_folder (str): Der Pfad zum Hauptordner mit den Frames.
    Returns:
        pd.DataFrame: Ein bereinigtes DataFrame mit allen Werbungen und kombinierten Texten.
    """
    # Lade alle Frames
    frames = load_all_frames(input_folder)
    
    # Führe OCR auf allen Frames durch und entfernt Wasserzeichen
    ocr_df = process_frames_with_watermark_removal(frames, x, y, w, h, method)
    
    # df frames sortieren
    sorted_ocr_df = sort_frames(ocr_df,"Frame")

    #2 Bereinige und kombiniere die Texte
    final_ocr_df = create_cleaned_dataframe(sorted_ocr_df,text_column="Recognized_Text", threshold=50)

    # Daten mit Wörterbuch abgleichen und 
    final_ocr_df["cleaned_text"] = final_ocr_df["recognized_text"].apply(clean_recognized_text_with_spacy)
    
        
    return cleaned_df

# %%
input_folder = os.getenv("INPUT_FRAMES_ALL")  # Oder setze den Pfad direkt: "path/to/frames"

# %%
# Hauptskript
x, y, w, h = 62, 545, 235, 60  # Anpassen, falls nötig
method = "black"
threshold = 60

# 1. Lade alle Frames
frames = load_all_frames(input_folder)

print(f"Anzahl der geladenen Frames: {len(frames)}")
print(f"Anzahl der unterschiedlichen Werbungen: {len(set([frame['ad'] for frame in frames]))}")

# 2. Entferne Wasserzeichen und führe OCR aus
ocr_results_df = process_frames_with_watermark_removal(frames, x, y, w, h, method)
# Out:
# Anzahl der geladenen Frames: 64981
# Anzahl der unterschiedlichen Werbungen: 537

# %%
ocr_results_df
# Out:
#                        Frame                 Recognized_Text      ad
# 0      AD0252_Frame_1610.png                        Bravery:  AD0252
# 1      AD0252_Frame_1620.png                        Bravery:  AD0252
# 2      AD0252_Frame_1630.png                        Bravery:  AD0252
# 3      AD0252_Frame_1640.png  Bravery: It'5 what defines us.  AD0252
# 4      AD0252_Frame_1650.png  Bravery: It's what defines us.  AD0252
# ...                      ...                             ...     ...
# 23657   AD0801_Frame_610.png                              FN  AD0801
# 23658   AD0801_Frame_810.png                        Wea, ;om  AD0801
# 23659   AD0801_Frame_820.png                WeatherTeche_com  AD0801
# 23660   AD0801_Frame_830.png                WeatherTeche_com  AD0801
# 23661   AD0801_Frame_840.png                WeatherTeche_com  AD0801
#
# [23662 rows x 3 columns]

# %%
# 3. Bereinige die Ergebnisse und kombiniere Texte
final_results_df = create_cleaned_dataframe(ocr_results_df, text_column="Recognized_Text", threshold=60)

# 4. Zeige die Ergebnisse
from IPython.display import display
display(final_results_df)
# Out:
#          ad                                    recognized_text
# 0    AD0252  Bravery:; Bravery: It'5 what defines us.; Audi...
# 1    AD0253  AFF, MEEP; Ficlionalizalion; Acllowallzallou; ...
# 2    AD0254  soluor CNRAL, Sprint, #Mobile:, atet; MCINTRAL...
# 3    AD0255  Screen images suulal; 112z8; Fuzt;; 1e04213; s...
# 4    AD0256  BECKS, SAPPHII; bEck:, ALC /Vol, BECKS, SAPPHI...
# ..      ...                                                ...
# 530  AD0797  Uber, Eats; Foil, Aluminum; Prop food Do not e...
# 531  AD0798  verizon, 12tia007; Signupat verizon com/SG, 5G...
# 532  AD0799  3i, Go, Le ta, (STop, talae, Wae, Weun; (STop,...
# 533  AD0800  20,2012. Seth T. was struck by lightning:, May...
# 534  AD0801  els; WeatherTech', WeatherTech, WeatherTech'; ...
#
# [535 rows x 2 columns]
# Ergebnisse wurden erfolgreich in 'final_ocr_results.csv' gespeichert.

# %% [markdown]
# ### ENCHANT für Rechtschreibkorrektur + NER Modell für Erkennung von Markenname und Produktname

# %%
import re
import enchant

# Wörterbuch für Englisch
english_dict = enchant.Dict("en_US")

# %%
# Funktion, um zu prüfen, ob ein Wort korrekt ist
def is_word_correct(word):
    return checker.check(word)

# Beispielwörter
words = ["correct", "speling", "WiFi", "ridgeline","isn't","Don't","we'll","won't"]

# Ergebnis prüfen
for word in words:
    print(f"{word}: {'richtig' if is_word_correct(word) else 'falsch'}")
# Out:
# correct: richtig
# speling: falsch
# WiFi: richtig
# ridgeline: falsch
# isn't: richtig
# Don't: richtig
# we'll: richtig
# won't: richtig

# %%
# Textverarbeitung
text = "Audi Honda Ebay Axes introduces the new Ridgeline RTL in 2024 Ridgeline isn't."
doc = nlp(text)

# Entitäten anzeigen
for ent in doc.ents:
    print(f"Text: {ent.text}, Typ: {ent.label_}")
# Out:
# Text: Audi, Typ: ORG
# Text: Honda, Typ: ORG
# Text: Ebay Axes, Typ: ORG
# Text: Ridgeline RTL, Typ: FAC
# Text: 2024, Typ: CARDINAL
# Text: Ridgeline, Typ: GPE

# %% [markdown]
# ### mit Spacy

# %%
import re
import enchant
import spacy

# Wörterbuch für Englisch
english_dict = enchant.Dict("en_US")

# Lade spaCy-Modell
nlp = spacy.load("en_core_web_md")

def clean_recognized_text_with_spacy(text):
    """
    Bereinigt erkannte Texte und prüft Wörter auf ihre Gültigkeit basierend auf einem Wörterbuch (enchant)
    und Named Entity Recognition (NER) mit spaCy.
    
    Args:
        text (str): Eingabetext (eine lange Zeichenkette).
        
    Returns:
        str: Bereinigter Text.
    """
    # 1. Bindestriche durch Leerzeichen ersetzen. Sonderzeichen entfernen, nur alphanumerische Zeichen und Leerzeichen behalten
    cleaned_text0 = re.sub(r"-", " ", text)
    cleaned_text1 = re.sub(r"[^\w\s']|(?<=\s)'|'(?=\s)", "", cleaned_text0)
    cleaned_text = re.sub(r"(?<=\w)'(?!\w)", "", cleaned_text1)
    print("Bereinigter Text ohne Sonderzeichen:", cleaned_text)

    # 2. Text in Wörter aufteilen und in Kleinbuchstaben umwandeln
    words_in_text = cleaned_text.split()
    print("Aufgeteilte Wörter (Kleinschreibung):", words_in_text)

    # 3. spaCy Named Entity Recognition (NER)
    doc = nlp(cleaned_text)
    recognized_entities = {ent.text.lower() for ent in doc.ents}
    print("Von spaCy erkannte Entitäten:", recognized_entities)

    # 4. Filtere Wörter basierend auf Wörterbuch und spaCy-Entitäten
    meaningful_words = [
        word for word in words_in_text
        if english_dict.check(word) or word.lower() in recognized_entities
    ]

    # 5. Bereinige den Text, indem nur relevante Wörter beibehalten werden
    final_cleaned_text = " ".join(meaningful_words)
    return final_cleaned_text

# %%
text = "isn't 903, Closed Course, obey speed ard traffic laws;, Aluys; PRINCIPAL, ONLY; PRINCE; PathctpaE, BHrSoN, ISQHIOOL, Hu; Bravery:; Bravery: It'5 what defines us.; Audi, CW), Truth in Engineering, #BraveryWins; SCORING SUMMARY, BALTIMORE, PLAYS 6, Art, YARDS 51, RAVENS, TIME 2:29, Jin: 13-YARD TD RECEPTION"

print(clean_recognized_text_with_spacy(text))
# Out:
# Bereinigter Text ohne Sonderzeichen: isnt 903 Closed Course obey speed ard traffic laws Aluys PRINCIPAL ONLY PRINCE PathctpaE BHrSoN ISQHIOOL Hu Bravery Bravery It5 what defines us Audi CW Truth in Engineering BraveryWins SCORING SUMMARY BALTIMORE PLAYS 6 Art YARDS 51 RAVENS TIME 229 Jin 13 YARD TD RECEPTION
# Aufgeteilte Wörter (Kleinschreibung): ['isnt', '903', 'Closed', 'Course', 'obey', 'speed', 'ard', 'traffic', 'laws', 'Aluys', 'PRINCIPAL', 'ONLY', 'PRINCE', 'PathctpaE', 'BHrSoN', 'ISQHIOOL', 'Hu', 'Bravery', 'Bravery', 'It5', 'what', 'defines', 'us', 'Audi', 'CW', 'Truth', 'in', 'Engineering', 'BraveryWins', 'SCORING', 'SUMMARY', 'BALTIMORE', 'PLAYS', '6', 'Art', 'YARDS', '51', 'RAVENS', 'TIME', '229', 'Jin', '13', 'YARD', 'TD', 'RECEPTION']
# Von spaCy erkannte Entitäten: {'51', '903', 'audi cw truth', 'isqhiool hu bravery bravery', 'baltimore', '229', 'ravens time'}
# 903 Closed Course obey speed traffic laws PRINCIPAL ONLY PRINCE Bravery Bravery what defines us Audi CW Truth in Engineering SCORING SUMMARY BALTIMORE PLAYS 6 Art YARDS 51 RAVENS TIME 229 YARD TD RECEPTION

# %%
zwischenergebnis["cleaned_text"] = zwischenergebnis["recognized_text"].apply(clean_recognized_text_with_spacy)

#Speichere die Ergebnisse
zwischenergebnis.to_csv("test_ocr_to_merge.csv", index=False)
print("Ergebnisse wurden erfolgreich in 'ocr_to_merge.csv' gespeichert.")
# Out:
# Bereinigter Text ohne Sonderzeichen: '3n Closed course  Alays obey speed and traffic aws PRINCIPAL ONLY PRINCE PathctpaE BHrSoN ISQHIOOL Hu Bravery Bravery It's what defines us Audi CW Truth in Engineering BraveryWins Away Fiel 22 SCORING SUMMARY BALTIMORE ANQUAN BOLDIN AtH REC TD THIS POSTSEASON MFD Art 4 REC TD IN REG SEASON RAVENS
# Aufgeteilte Wörter (Kleinschreibung): ["'3n", 'Closed', 'course', 'Alays', 'obey', 'speed', 'and', 'traffic', 'aws', 'PRINCIPAL', 'ONLY', 'PRINCE', 'PathctpaE', 'BHrSoN', 'ISQHIOOL', 'Hu', 'Bravery', 'Bravery', "It's", 'what', 'defines', 'us', 'Audi', 'CW', 'Truth', 'in', 'Engineering', 'BraveryWins', 'Away', 'Fiel', '22', 'SCORING', 'SUMMARY', 'BALTIMORE', 'ANQUAN', 'BOLDIN', 'AtH', 'REC', 'TD', 'THIS', 'POSTSEASON', 'MFD', 'Art', '4', 'REC', 'TD', 'IN', 'REG', 'SEASON', 'RAVENS']
# Von spaCy erkannte Entitäten: {'ravens', 'baltimore anquan boldin', '22', '4', 'audi cw truth', 'isqhiool hu bravery bravery', "'3n"}
# Bereinigter Text ohne Sonderzeichen: NFF WEEP  MeFP OF Ficiionalizalion  Acllowallzallou FuMula sWnon nothinG BEA 5 An ASTRONAUT Unilever Jllc NEW AxE APOLLO ENTER BEFORE MIDNIGHT AT AXEAPOLLO COM No purchase neressary Void where prohibieck AXE Apallo Bia Game Sweapslakcs is sponsared by Gonopca Inc  ba Unilevct Open lo legalie sclerds Ollie JOUS  DC 180r ulder Beyins 1913a10G00OOPT  ends 2313at 1 5939pmn PT Forollicial rule s visit a cacollocom
# Aufgeteilte Wörter (Kleinschreibung): ['NFF', 'WEEP', 'MeFP', 'OF', 'Ficiionalizalion', 'Acllowallzallou', 'FuMula', 'sWnon', 'nothinG', 'BEA', '5', 'An', 'ASTRONAUT', 'Unilever', 'Jllc', 'NEW', 'AxE', 'APOLLO', 'ENTER', 'BEFORE', 'MIDNIGHT', 'AT', 'AXEAPOLLO', 'COM', 'No', 'purchase', 'neressary', 'Void', 'where', 'prohibieck', 'AXE', 'Apallo', 'Bia', 'Game', 'Sweapslakcs', 'is', 'sponsared', 'by', 'Gonopca', 'Inc', 'ba', 'Unilevct', 'Open', 'lo', 'legalie', 'sclerds', 'Ollie', 'JOUS', 'DC', '180r', 'ulder', 'Beyins', '1913a10G00OOPT', 'ends', '2313at', '1', '5939pmn', 'PT', 'Forollicial', 'rule', 's', 'visit', 'a', 'cacollocom']
# Von spaCy erkannte Entitäten: {'void', 'gonopca inc  ', 'mefp of ficiionalizalion', 'apollo', 'dc 180r', '1913a10g00oopt', '1 5939pmn', 'axeapollo', 'ollie jous  ', 'beyins', 'unilever', 'acllowallzallou fumula swnon', 'pt forollicial', 'nff weep  '}
# Bereinigter Text ohne Sonderzeichen: 88p Wrot JTe Je Aneeaa Eorn Ione Kae sobi 4a Novaa colUnor CNTRAL T  Mobile verizon atet JRE MAGIC RY MO ENT veriz Kov churcirotc 4EADPHONES HEADPH OW PRICE FREE DELIVERY RANTEE ON ALL MAJOP APPLIANCFC MOVIES  MUSIC HOME APPLIANCES PTURF EmaGiG TOP RATED SLR CAMERAS MA WWeeen  LAPTOPS 30 Li0n LMTOFS LAPTOPS BEST BUY EXC BEST BUY CREATIVITY UR SLEEK AN Screen Images Simuated Nton TEST TABLETS GHT HERE THOUSANDS OF EXPERTS IE plebs and cReaders under one fool ARL READY TO HELP BESTI BUY InfiniteAnswers JBVSoufons c A Rghs Respned BEST BUK He BESTE bebydesgo Besbuyoomae hzdeta_s OFBBV Souots hc BUlgo  SOLUTION CENTRAL Any E CAraER AnypHGTE Sprint All MoNe puce
# Aufgeteilte Wörter (Kleinschreibung): ['88p', 'Wrot', 'JTe', 'Je', 'Aneeaa', 'Eorn', 'Ione', 'Kae', 'sobi', '4a', 'Novaa', 'colUnor', 'CNTRAL', 'T', 'Mobile', 'verizon', 'atet', 'JRE', 'MAGIC', 'RY', 'MO', 'ENT', 'veriz', 'Kov', 'churcirotc', '4EADPHONES', 'HEADPH', 'OW', 'PRICE', 'FREE', 'DELIVERY', 'RANTEE', 'ON', 'ALL', 'MAJOP', 'APPLIANCFC', 'MOVIES', 'MUSIC', 'HOME', 'APPLIANCES', 'PTURF', 'EmaGiG', 'TOP', 'RATED', 'SLR', 'CAMERAS', 'MA', 'WWeeen', 'LAPTOPS', '30', 'Li0n', 'LMTOFS', 'LAPTOPS', 'BEST', 'BUY', 'EXC', 'BEST', 'BUY', 'CREATIVITY', 'UR', 'SLEEK', 'AN', 'Screen', 'Images', 'Simuated', 'Nton', 'TEST', 'TABLETS', 'GHT', 'HERE', 'THOUSANDS', 'OF', 'EXPERTS', 'IE', 'plebs', 'and', 'cReaders', 'under', 'one', 'fool', 'ARL', 'READY', 'TO', 'HELP', 'BESTI', 'BUY', 'InfiniteAnswers', 'JBVSoufons', 'c', 'A', 'Rghs', 'Respned', 'BEST', 'BUK', 'He', 'BESTE', 'bebydesgo', 'Besbuyoomae', 'hzdeta_s', 'OFBBV', 'Souots', 'hc', 'BUlgo', 'SOLUTION', 'CENTRAL', 'Any', 'E', 'CAraER', 'AnypHGTE', 'Sprint', 'All', 'MoNe', 'puce']
# Von spaCy erkannte Entitäten: {'ione kae', 'je aneeaa', 'wweeen', 'jre magic', 'ofbbv souots', 'mo', 'kov', 'sprint', 'novaa', 'music home appliances pturf', 'arl', 'thousands', 'creaders', 'rantee', 'beste', 'mobile', 'cntral', '4eadphones', '4a', '88p', 'besbuyoomae hzdeta_s', '30'}
# Bereinigter Text ohne Sonderzeichen: Screen images simulated Ver Miayes Slanu 112z8 Fuzt 1e04213 Coming soon lo select US carriers STOP Iff BlackBerry See what it can do at blackberry comzlo BlackBery Blnck Rorry Hub annie Malthowe Mcllss Davcy Hisham Athas Revlw02 Sales Mch Mutu Mtr BlackBerry Steptuan Dutke Trevor Camcron See what it can do at blackberry comzlo Annle Mattnowt BlackBery
# Aufgeteilte Wörter (Kleinschreibung): ['Screen', 'images', 'simulated', 'Ver', 'Miayes', 'Slanu', '112z8', 'Fuzt', '1e04213', 'Coming', 'soon', 'lo', 'select', 'US', 'carriers', 'STOP', 'Iff', 'BlackBerry', 'See', 'what', 'it', 'can', 'do', 'at', 'blackberry', 'comzlo', 'BlackBery', 'Blnck', 'Rorry', 'Hub', 'annie', 'Malthowe', 'Mcllss', 'Davcy', 'Hisham', 'Athas', 'Revlw02', 'Sales', 'Mch', 'Mutu', 'Mtr', 'BlackBerry', 'Steptuan', 'Dutke', 'Trevor', 'Camcron', 'See', 'what', 'it', 'can', 'do', 'at', 'blackberry', 'comzlo', 'Annle', 'Mattnowt', 'BlackBery']
# Von spaCy erkannte Entitäten: {'malthowe mcllss', 'trevor camcron', 'ver miayes', 'mattnowt blackbery', 'us', 'blnck rorry hub'}
# Bereinigter Text ohne Sonderzeichen: BECK  LGAA BecKS SAPPHIRE Ied otn BECKS SAPPHIRE MAN SAPPHIRE SMOOTH TASTE HOPS becks ALC Vol BECK  SAPPHIRE Ba Sapphire Hoes moothtaSTe bEcKs LG NVol BECKS SAPPHIRE Tucath aatt RE PS Mta REG BEC 769 6 RTG BEd BECKS TALc Ivol becK  APPHird Panftia Pbhi 6Ecro Cvoi Lc DECI5 JR bECKS THEST Galcvol cI FT OUR BECK SMOOTHEST Ac ro BECKS YET Kecis SAPPHIRE Always Ebv Responsibly 2013 Brauatel Beck  Co  Beck Spbuppl Ncer SL Louls MO OUR BECKs SMOOTHEST Acor BECKS YET Wccis SAPPHIRE Always Enjoy Responsibly 092018 Brauarel Beck  Co  Beck SQ Sapphlre Dcor SL Louls MO
# Aufgeteilte Wörter (Kleinschreibung): ['BECK', 'LGAA', 'BecKS', 'SAPPHIRE', 'Ied', 'otn', 'BECKS', 'SAPPHIRE', 'MAN', 'SAPPHIRE', 'SMOOTH', 'TASTE', 'HOPS', 'becks', 'ALC', 'Vol', 'BECK', 'SAPPHIRE', 'Ba', 'Sapphire', 'Hoes', 'moothtaSTe', 'bEcKs', 'LG', 'NVol', 'BECKS', 'SAPPHIRE', 'Tucath', 'aatt', 'RE', 'PS', 'Mta', 'REG', 'BEC', '769', '6', 'RTG', 'BEd', 'BECKS', 'TALc', 'Ivol', 'becK', 'APPHird', 'Panftia', 'Pbhi', '6Ecro', 'Cvoi', 'Lc', 'DECI5', 'JR', 'bECKS', 'THEST', 'Galcvol', 'cI', 'FT', 'OUR', 'BECK', 'SMOOTHEST', 'Ac', 'ro', 'BECKS', 'YET', 'Kecis', 'SAPPHIRE', 'Always', 'Ebv', 'Responsibly', '2013', 'Brauatel', 'Beck', 'Co', 'Beck', 'Spbuppl', 'Ncer', 'SL', 'Louls', 'MO', 'OUR', 'BECKs', 'SMOOTHEST', 'Acor', 'BECKS', 'YET', 'Wccis', 'SAPPHIRE', 'Always', 'Enjoy', 'Responsibly', '092018', 'Brauarel', 'Beck', 'Co', 'Beck', 'SQ', 'Sapphlre', 'Dcor', 'SL', 'Louls', 'MO']
# Von spaCy erkannte Entitäten: {'beck sq sapphlre', 'panftia pbhi', 'cvoi lc deci5 jr', 'lg', 'sapphire ba', 'ebv responsibly', 'beck', 'vol beck  ', 'mo', 'lgaa becks sapphire ied otn', 'ps mta reg', '769', 'dcor', '2013', 'sl louls', 'brauarel beck  co', 'ivol', 'beck spbuppl ncer', 'rtg', 'becks', 'thest galcvol ci'}
# Bereinigter Text ohne Sonderzeichen: euttedser BLACK CAOWI U AoLoEleeetn ENJOY RESPONSIBLY 02013 A B BuDwEIsER Blaok CROWN LAGER ST Louis MO MACK CAOWA Lo aLcnd NEW FBudoseisek BLACK CROWN BLACK CROWN
# Aufgeteilte Wörter (Kleinschreibung): ['euttedser', 'BLACK', 'CAOWI', 'U', 'AoLoEleeetn', 'ENJOY', 'RESPONSIBLY', '02013', 'A', 'B', 'BuDwEIsER', 'Blaok', 'CROWN', 'LAGER', 'ST', 'Louis', 'MO', 'MACK', 'CAOWA', 'Lo', 'aLcnd', 'NEW', 'FBudoseisek', 'BLACK', 'CROWN', 'BLACK', 'CROWN']
# Von spaCy erkannte Entitäten: {'b budweiser blaok crown lager', 'st louis mo mack', '02013', 'euttedser black caowi u aoloeleeetn'}
# Bereinigter Text ohne Sonderzeichen: croln WAck CMowh McTcm ucK Mccnuat Enjoy ReapOnSIBLY 02013 A  B BuawEIsEn Buck CnowN LAGEn ST Lours MO NJoy RESRONSIBL ia B BUSNELRW Blaci S7 Louie MQ ha AGER TucK CAOM Lot NEW FBudieioed BLACK CROWN BLACK CROWN
# Aufgeteilte Wörter (Kleinschreibung): ['croln', 'WAck', 'CMowh', 'McTcm', 'ucK', 'Mccnuat', 'Enjoy', 'ReapOnSIBLY', '02013', 'A', 'B', 'BuawEIsEn', 'Buck', 'CnowN', 'LAGEn', 'ST', 'Lours', 'MO', 'NJoy', 'RESRONSIBL', 'ia', 'B', 'BUSNELRW', 'Blaci', 'S7', 'Louie', 'MQ', 'ha', 'AGER', 'TucK', 'CAOM', 'Lot', 'NEW', 'FBudieioed', 'BLACK', 'CROWN', 'BLACK', 'CROWN']
# Von spaCy erkannte Entitäten: {'mccnuat', 'buck cnown lagen', 'resronsibl ia b busnelrw blaci s7 louie mq', 'mctcm', '02013', 'st lours mo', 'caom lot'}
# Bereinigter Text ohne Sonderzeichen: 8243 IStadIuM Ustadiun 8248 Ocom Ane edn D0o 238 BuD UNT Shon Aqess Bar ELD 88 LISNT EuD Da Ga Gd TRANC 1 ITS ONLY WEIRD IF IT DOESN'T WORK BuE HEREWEGO BUD LIGH  TKD FLVI alt aaeen EMJOY RESPONSLBLY 2013 ANHCUSCR DUSCH BUD LIGHT dCer ST  LOUIS MO
# Aufgeteilte Wörter (Kleinschreibung): ['8243', 'IStadIuM', 'Ustadiun', '8248', 'Ocom', 'Ane', 'edn', 'D0o', '238', 'BuD', 'UNT', 'Shon', 'Aqess', 'Bar', 'ELD', '88', 'LISNT', 'EuD', 'Da', 'Ga', 'Gd', 'TRANC', '1', 'ITS', 'ONLY', 'WEIRD', 'IF', 'IT', "DOESN'T", 'WORK', 'BuE', 'HEREWEGO', 'BUD', 'LIGH', 'TKD', 'FLVI', 'alt', 'aaeen', 'EMJOY', 'RESPONSLBLY', '2013', 'ANHCUSCR', 'DUSCH', 'BUD', 'LIGHT', 'dCer', 'ST', 'LOUIS', 'MO']
# Von spaCy erkannte Entitäten: {'8243', 'lisnt', '238', 'da ga', 'emjoy responslbly 2013', 'eud', 'louis mo', 'shon', 'dcer st'}
# Bereinigter Text ohne Sonderzeichen: ABudtcisor curbe SBudwciser CLDLUDal JNAL THREE YEARS LATER AC VOU Coming to Things ppening Clydesdales Budweiser Chicago 7605 6as UBudoveisehe CLYDESDALES ENjoy RESPONSIBLY 02013 ANHEUSER BuScH BuDwEISER BEER St Louis MO
# Aufgeteilte Wörter (Kleinschreibung): ['ABudtcisor', 'curbe', 'SBudwciser', 'CLDLUDal', 'JNAL', 'THREE', 'YEARS', 'LATER', 'AC', 'VOU', 'Coming', 'to', 'Things', 'ppening', 'Clydesdales', 'Budweiser', 'Chicago', '7605', '6as', 'UBudoveisehe', 'CLYDESDALES', 'ENjoy', 'RESPONSIBLY', '02013', 'ANHEUSER', 'BuScH', 'BuDwEISER', 'BEER', 'St', 'Louis', 'MO']
# Von spaCy erkannte Entitäten: {'three years later', 'curbe sbudwciser cldludal jnal', 'clydesdales budweiser', 'clydesdales', '7605 6as', 'anheuser'}
# Bereinigter Text ohne Sonderzeichen: Calvin Klein Klein Calvin Kicin Vin Clt i calic C 0 N  E P T Calvin Klein C 0 N C E P T calvinkleincom calvinklein
# Aufgeteilte Wörter (Kleinschreibung): ['Calvin', 'Klein', 'Klein', 'Calvin', 'Kicin', 'Vin', 'Clt', 'i', 'calic', 'C', '0', 'N', 'E', 'P', 'T', 'Calvin', 'Klein', 'C', '0', 'N', 'C', 'E', 'P', 'T', 'calvinkleincom', 'calvinklein']
# Von spaCy erkannte Entitäten: {'calvin kicin vin clt', 'calvin klein'}
# Bereinigter Text ohne Sonderzeichen: cots com carscom Fld carscom ALL DRIVE No drama nodrama Gale com
# Aufgeteilte Wörter (Kleinschreibung): ['cots', 'com', 'carscom', 'Fld', 'carscom', 'ALL', 'DRIVE', 'No', 'drama', 'nodrama', 'Gale', 'com']
# Von spaCy erkannte Entitäten: {'fld'}
# Bereinigter Text ohne Sonderzeichen: SMARTER BOLDER C21COM Century 21 Real Estate LLC Realoey Compan CEMTURY 210 and SHARTER BOLDER FASTER  are Replstered Trademarks Oxned By Century Real Estate LLC An Equal Opportunity Company Equal Housing Opportunely  Each CENTURY 21 Oce Independently Owcned Operated Cluy2l
# Aufgeteilte Wörter (Kleinschreibung): ['SMARTER', 'BOLDER', 'C21COM', 'Century', '21', 'Real', 'Estate', 'LLC', 'Realoey', 'Compan', 'CEMTURY', '210', 'and', 'SHARTER', 'BOLDER', 'FASTER', 'are', 'Replstered', 'Trademarks', 'Oxned', 'By', 'Century', 'Real', 'Estate', 'LLC', 'An', 'Equal', 'Opportunity', 'Company', 'Equal', 'Housing', 'Opportunely', 'Each', 'CENTURY', '21', 'Oce', 'Independently', 'Owcned', 'Operated', 'Cluy2l']
# Von spaCy erkannte Entitäten: {'replstered trademarks oxned by century real estate llc an equal opportunity company equal housing opportunely  each century 21'}
# Bereinigter Text ohne Sonderzeichen: kcc tod Aca Kata Icg Cd Vicn Cc a 6cl Dula Companv Knd V9j5 Cxl h ojiWbWo1 tij6s  IoN 10966 Wb N u ciieu Eoufe Deseeue tjltetexwperele Me el U Cola 7Z64 Wpe apik Keseynylojul Bote Desion are reqistered Ea of Ine Coga Cola ompame 49 Ionidai lcaGca Traired Dadlander Do not alemn Edo Ia mowpl attompg Wadlaulele_Vo nutrattempi lcatcta MILES 50 MHLAD 50 ES lca tcl MhHab Vote now to decide who wins KeatrECHASECOM 50 Ica Gcl Mhhab
# Aufgeteilte Wörter (Kleinschreibung): ['kcc', 'tod', 'Aca', 'Kata', 'Icg', 'Cd', 'Vicn', 'Cc', 'a', '6cl', 'Dula', 'Companv', 'Knd', 'V9j5', 'Cxl', 'h', 'ojiWbWo1', 'tij6s', 'IoN', '10966', 'Wb', 'N', 'u', 'ciieu', 'Eoufe', 'Deseeue', 'tjltetexwperele', 'Me', 'el', 'U', 'Cola', '7Z64', 'Wpe', 'apik', 'Keseynylojul', 'Bote', 'Desion', 'are', 'reqistered', 'Ea', 'of', 'Ine', 'Coga', 'Cola', 'ompame', '49', 'Ionidai', 'lcaGca', 'Traired', 'Dadlander', 'Do', 'not', 'alemn', 'Edo', 'Ia', 'mowpl', 'attompg', 'Wadlaulele_Vo', 'nutrattempi', 'lcatcta', 'MILES', '50', 'MHLAD', '50', 'ES', 'lca', 'tcl', 'MhHab', 'Vote', 'now', 'to', 'decide', 'who', 'wins', 'KeatrECHASECOM', '50', 'Ica', 'Gcl', 'Mhhab']
# Von spaCy erkannte Entitäten: {'7z64', 'keatrechasecom 50', 'ea', 'keseynylojul', '50', 'ojiwbwo1', '49', 'dula companv knd', 'vicn cc', 'ionidai', 'edo', '10966', 'tod aca kata icg', 'ine coga cola', 'ica gcl mhhab', 'wb n', 'cxl', 'ion', 'eoufe deseeue', 'kcc', 'es lca', 'traired dadlander'}
# Bereinigter Text ohne Sonderzeichen: SECURITY CAMERAS AROUND FTHE WORLD ALSO CAPTURE PEOPLE STEALING MUSIC DDICTS Zmqin SUU I  SEPL2008 161940 HONEST CKPOCKETS E C Dia6a 22 79 1 2 AND POTATO CHIP EALERS 029  1208 2uug 090324 ATTACKS F FRIENDSHIP Ava1z4 Sbu38 4i LKT 0500 18 01 12 UNEXPECTED REMEN AND PEACEFUL H6 LSu ARRIORS 01122011 01 00 58233 QzA 21092007 451843 LET'S LOOK AT THE WORLD A LITTLE DIFFERENTLY ula Coke Open Happiness and the Contour Bottle Design are registered trademarks of the Coca Cola Company DOs CAMPEG 30090007 10447 LET'S LOOK AT THE WORLD A LITTLE DIFFERENTLY 6opeteXapep e GcGdl open happiness
# Aufgeteilte Wörter (Kleinschreibung): ['SECURITY', 'CAMERAS', 'AROUND', 'FTHE', 'WORLD', 'ALSO', 'CAPTURE', 'PEOPLE', 'STEALING', 'MUSIC', 'DDICTS', 'Zmqin', 'SUU', 'I', 'SEPL2008', '161940', 'HONEST', 'CKPOCKETS', 'E', 'C', 'Dia6a', '22', '79', '1', '2', 'AND', 'POTATO', 'CHIP', 'EALERS', '029', '1208', '2uug', '090324', 'ATTACKS', 'F', 'FRIENDSHIP', 'Ava1z4', 'Sbu38', '4i', 'LKT', '0500', '18', '01', '12', 'UNEXPECTED', 'REMEN', 'AND', 'PEACEFUL', 'H6', 'LSu', 'ARRIORS', '01122011', '01', '00', '58233', 'QzA', '21092007', '451843', "LET'S", 'LOOK', 'AT', 'THE', 'WORLD', 'A', 'LITTLE', 'DIFFERENTLY', 'ula', 'Coke', 'Open', 'Happiness', 'and', 'the', 'Contour', 'Bottle', 'Design', 'are', 'registered', 'trademarks', 'of', 'the', 'Coca', 'Cola', 'Company', 'DOs', 'CAMPEG', '30090007', '10447', "LET'S", 'LOOK', 'AT', 'THE', 'WORLD', 'A', 'LITTLE', 'DIFFERENTLY', '6opeteXapep', 'e', 'GcGdl', 'open', 'happiness']
# Von spaCy erkannte Entitäten: {'029', '6opetexapep', 'h6', 'the contour bottle design', '30090007 10447', '79', 'f friendship', 'the coca cola company dos', '161940', '22', '090324', '01122011 01', '451843', 'gcgdl', 'capture people stealing music ddicts zmqin', 'remen'}
# Bereinigter Text ohne Sonderzeichen: Paul Harvey 600 CASE Group LLC Cuute LovV SALES IndependenceLa Smoked Chorizo Sausage Strc ies  500 ToRTiIla Cnif Italian  awberre 600 To the farmer in all of uS  GUTS  CLORY RAMA GUTS CLORY RAM RanFrucke com Reerpiotiag 3 Sn GUTS CLORY RAM RamTrucks comKeepPlowing gistered trademark of Chrysler Group LLG The FFA emblem is a registered trademark of the National FFA Organization and used under license
# Aufgeteilte Wörter (Kleinschreibung): ['Paul', 'Harvey', '600', 'CASE', 'Group', 'LLC', 'Cuute', 'LovV', 'SALES', 'IndependenceLa', 'Smoked', 'Chorizo', 'Sausage', 'Strc', 'ies', '500', 'ToRTiIla', 'Cnif', 'Italian', 'awberre', '600', 'To', 'the', 'farmer', 'in', 'all', 'of', 'uS', 'GUTS', 'CLORY', 'RAMA', 'GUTS', 'CLORY', 'RAM', 'RanFrucke', 'com', 'Reerpiotiag', '3', 'Sn', 'GUTS', 'CLORY', 'RAM', 'RamTrucks', 'comKeepPlowing', 'gistered', 'trademark', 'of', 'Chrysler', 'Group', 'LLG', 'The', 'FFA', 'emblem', 'is', 'a', 'registered', 'trademark', 'of', 'the', 'National', 'FFA', 'Organization', 'and', 'used', 'under', 'license']
# Von spaCy erkannte Entitäten: {'cuute lovv', '500', 'clory ram ramtrucks', 'chrysler', 'paul harvey', '600', 'reerpiotiag', 'the national ffa organization', 'cnif italian', 'us', 'ffa'}
# Bereinigter Text ohne Sonderzeichen: Doritos Doritos Doln Che Doritd Ucho Doif Dorito Nacho Crct Doritos prids ritos an
# Aufgeteilte Wörter (Kleinschreibung): ['Doritos', 'Doritos', 'Doln', 'Che', 'Doritd', 'Ucho', 'Doif', 'Dorito', 'Nacho', 'Crct', 'Doritos', 'prids', 'ritos', 'an']
# Von spaCy erkannte Entitäten: {'dorito', 'nacho crct doritos', 'doritos doritos doln che doritd ucho'}
# Bereinigter Text ohne Sonderzeichen: Dorits Cheed Nacho Goat Sale Derito e0 Cheet pritol Duiitus poxite Chcs Ghcct Doritos Dalito Do dlories DGtos Joctto Dorito jorIto IOs Dor Trotot LC Doritt Chee Dori Chees Hhec Dorito orit  Dorios rito Dorite orito Qoritosdarito Io Gat Kod Doritos Doritos Ooritos Dorite Joritos Itos Joritos Joritos rtote Jor britos Jorita Joritos Aucho Jiton Guccs nor 42 bags later THE NEXT DAY Qo Jotf Voritos pote Dorito Joritos GOAT SALF Ol rito Iriic Dinoc GOAT SALF Don Auc Dorili onlts Wt Gur Do o0flto ch Oon Docit e Jorin Jros orito
# Aufgeteilte Wörter (Kleinschreibung): ['Dorits', 'Cheed', 'Nacho', 'Goat', 'Sale', 'Derito', 'e0', 'Cheet', 'pritol', 'Duiitus', 'poxite', 'Chcs', 'Ghcct', 'Doritos', 'Dalito', 'Do', 'dlories', 'DGtos', 'Joctto', 'Dorito', 'jorIto', 'IOs', 'Dor', 'Trotot', 'LC', 'Doritt', 'Chee', 'Dori', 'Chees', 'Hhec', 'Dorito', 'orit', 'Dorios', 'rito', 'Dorite', 'orito', 'Qoritosdarito', 'Io', 'Gat', 'Kod', 'Doritos', 'Doritos', 'Ooritos', 'Dorite', 'Joritos', 'Itos', 'Joritos', 'Joritos', 'rtote', 'Jor', 'britos', 'Jorita', 'Joritos', 'Aucho', 'Jiton', 'Guccs', 'nor', '42', 'bags', 'later', 'THE', 'NEXT', 'DAY', 'Qo', 'Jotf', 'Voritos', 'pote', 'Dorito', 'Joritos', 'GOAT', 'SALF', 'Ol', 'rito', 'Iriic', 'Dinoc', 'GOAT', 'SALF', 'Don', 'Auc', 'Dorili', 'onlts', 'Wt', 'Gur', 'Do', 'o0flto', 'ch', 'Oon', 'Docit', 'e', 'Jorin', 'Jros', 'orito']
# Von spaCy erkannte Entitäten: {'jiton guccs', 'joritos', 'dorits cheed', 'jor', 'don auc dorili', 'jorita joritos', 'doritos dalito', 'nacho goat', 'dor trotot lc', 'later the next day', 'ch oon docit e', 'joritos itos', '42', 'dorito joritos', 'qoritosdarito io gat', 'chcs ghcct', 'jotf voritos', 'joctto dorito', 'derito e0 cheet', 'dorito orit', 'jros', 'kod doritos', 'dgtos'}
# Bereinigter Text ohne Sonderzeichen: edata basedon muliple independent souroes alu zyvaydevendlngon ndlvidual vesiorcicunstalces Professional stunts Donotattenpt E XTRADE LESS FOR US MORE FOR YOU etrade com You must be 18 years ofage to open an ETRADE Securties account Securities products and services are offered by ETRADE Securities LLC Member FINRNSHPC System response and account access times willvary 02013 ETRADE Financial Corporation
# Aufgeteilte Wörter (Kleinschreibung): ['edata', 'basedon', 'muliple', 'independent', 'souroes', 'alu', 'zyvaydevendlngon', 'ndlvidual', 'vesiorcicunstalces', 'Professional', 'stunts', 'Donotattenpt', 'E', 'XTRADE', 'LESS', 'FOR', 'US', 'MORE', 'FOR', 'YOU', 'etrade', 'com', 'You', 'must', 'be', '18', 'years', 'ofage', 'to', 'open', 'an', 'ETRADE', 'Securties', 'account', 'Securities', 'products', 'and', 'services', 'are', 'offered', 'by', 'ETRADE', 'Securities', 'LLC', 'Member', 'FINRNSHPC', 'System', 'response', 'and', 'account', 'access', 'times', 'willvary', '02013', 'ETRADE', 'Financial', 'Corporation']
# Von spaCy erkannte Entitäten: {'etrade securities llc', 'edata basedon muliple', 'zyvaydevendlngon', '02013', '18 years', 'us'}
# Bereinigter Text ohne Sonderzeichen: Rd Mt eeref Sid Janot Jeot Degt IT'S ABOUT TIME YOU HAD FAVORITE T SHIRT GILDAN EVERY THREAD COUNTS
# Aufgeteilte Wörter (Kleinschreibung): ['Rd', 'Mt', 'eeref', 'Sid', 'Janot', 'Jeot', 'Degt', "IT'S", 'ABOUT', 'TIME', 'YOU', 'HAD', 'FAVORITE', 'T', 'SHIRT', 'GILDAN', 'EVERY', 'THREAD', 'COUNTS']
# Von spaCy erkannte Entitäten: {'sid janot', 'rd mt'}
# Bereinigter Text ohne Sonderzeichen: Iddy Ss Ga Daddy COM Iddy Jkiss WHEN SEXY MEETS SMART YOUR SMALL BUSINESS SCORES Jkiss GET YOUR DOMAIN AND WEBSITE Go Daddycos SEE MORE NOW AT GODADDYCOM
# Aufgeteilte Wörter (Kleinschreibung): ['Iddy', 'Ss', 'Ga', 'Daddy', 'COM', 'Iddy', 'Jkiss', 'WHEN', 'SEXY', 'MEETS', 'SMART', 'YOUR', 'SMALL', 'BUSINESS', 'SCORES', 'Jkiss', 'GET', 'YOUR', 'DOMAIN', 'AND', 'WEBSITE', 'Go', 'Daddycos', 'SEE', 'MORE', 'NOW', 'AT', 'GODADDYCOM']
# Von spaCy erkannte Entitäten: {'daddycos', 'iddy jkiss', 'jkiss', 'iddy ss ga'}
# Bereinigter Text ohne Sonderzeichen: Daddy Co Co pdmrrai Daddy CO Co 4IA 03mn Daddy Co F04 Brnntd UUanea ARIh AnRzMI DNntetau Youl Co rBigldea Co
# Aufgeteilte Wörter (Kleinschreibung): ['Daddy', 'Co', 'Co', 'pdmrrai', 'Daddy', 'CO', 'Co', '4IA', '03mn', 'Daddy', 'Co', 'F04', 'Brnntd', 'UUanea', 'ARIh', 'AnRzMI', 'DNntetau', 'Youl', 'Co', 'rBigldea', 'Co']
# Von spaCy erkannte Entitäten: {'daddy co co', 'youl co rbigldea co', 'daddy co co 4ia 03mn'}
# Bereinigter Text ohne Sonderzeichen: 100 BANK NK AerAll G7 MI CIRMS CIR CIR culnijs CIRA Mk 01 IIS MILK MMila HLK rlla MMil Milk MILK Protein to start your day gofmilk milkmustachecom AMERICA SMILK PROCESSORS
# Aufgeteilte Wörter (Kleinschreibung): ['100', 'BANK', 'NK', 'AerAll', 'G7', 'MI', 'CIRMS', 'CIR', 'CIR', 'culnijs', 'CIRA', 'Mk', '01', 'IIS', 'MILK', 'MMila', 'HLK', 'rlla', 'MMil', 'Milk', 'MILK', 'Protein', 'to', 'start', 'your', 'day', 'gofmilk', 'milkmustachecom', 'AMERICA', 'SMILK', 'PROCESSORS']
# Von spaCy erkannte Entitäten: {'100', 'g7 mi cirms', 'america smilk', '01', 'cir', 'cira', 'bank nk aerall'}
# Bereinigter Text ohne Sonderzeichen: aplespm IIeIN ablluspnng ablcsn enicie available spring 2013 anempl UO TIOL auempt auon Do not attempt CutpL nEW thinkinG hyundai nEW POSSIBILITIES Pick Your Team Hyundaicom
# Aufgeteilte Wörter (Kleinschreibung): ['aplespm', 'IIeIN', 'ablluspnng', 'ablcsn', 'enicie', 'available', 'spring', '2013', 'anempl', 'UO', 'TIOL', 'auempt', 'auon', 'Do', 'not', 'attempt', 'CutpL', 'nEW', 'thinkinG', 'hyundai', 'nEW', 'POSSIBILITIES', 'Pick', 'Your', 'Team', 'Hyundaicom']
# Von spaCy erkannte Entitäten: {'hyundai', 'new possibilities pick your team hyundaicom', 'spring 2013', 'iiein', 'tiol'}
# Bereinigter Text ohne Sonderzeichen: 451070 7SL0 70 15 3 Idnygen 45 45 onngea  tlon Hawoas EMD FRIN Kons nuwGu oy leaks _ EMD GhiN Prototype for 2014 Sonata Turbo shown Production model may vary Available later this year nEW thinkinG hyundai nEW POSSIBILITIES You Tube Hyundaicom
# Aufgeteilte Wörter (Kleinschreibung): ['451070', '7SL0', '70', '15', '3', 'Idnygen', '45', '45', 'onngea', 'tlon', 'Hawoas', 'EMD', 'FRIN', 'Kons', 'nuwGu', 'oy', 'leaks', '_', 'EMD', 'GhiN', 'Prototype', 'for', '2014', 'Sonata', 'Turbo', 'shown', 'Production', 'model', 'may', 'vary', 'Available', 'later', 'this', 'year', 'nEW', 'thinkinG', 'hyundai', 'nEW', 'POSSIBILITIES', 'You', 'Tube', 'Hyundaicom']
# Von spaCy erkannte Entitäten: {'hyundai', 'emd', 'later this year', '70 15 3', 'hawoas', '451070', '45 45 onngea  tlon', '2014', 'sonata turbo'}
# Bereinigter Text ohne Sonderzeichen: G6 We wait We hope G6 We wait We hope We pray G6 We wait We hope We pray Until you're home again Oprah Oprah Klc Mofh Jo4k EPiZ Claim SAF RETUI WaangLer nLiMITeD Jeep hankia Pof 4eto Jg Cndn 4S hakih I Wf qVR Mi TR RH Mz 1EHEJJ weleh TI 8IE Oiui R16 Aa Cene WusD Lu50 EuSo Dniand PROUDLY SUPPORTING OUR NATION'S HEROES THE BEST OF WHAT WE'RE MADE OF Jeep u8o HeernCEP FUSO Jeep comOSR Jeep is  registered trademark of Chrysler Group LLC Jeep
# Aufgeteilte Wörter (Kleinschreibung): ['G6', 'We', 'wait', 'We', 'hope', 'G6', 'We', 'wait', 'We', 'hope', 'We', 'pray', 'G6', 'We', 'wait', 'We', 'hope', 'We', 'pray', 'Until', "you're", 'home', 'again', 'Oprah', 'Oprah', 'Klc', 'Mofh', 'Jo4k', 'EPiZ', 'Claim', 'SAF', 'RETUI', 'WaangLer', 'nLiMITeD', 'Jeep', 'hankia', 'Pof', '4eto', 'Jg', 'Cndn', '4S', 'hakih', 'I', 'Wf', 'qVR', 'Mi', 'TR', 'RH', 'Mz', '1EHEJJ', 'weleh', 'TI', '8IE', 'Oiui', 'R16', 'Aa', 'Cene', 'WusD', 'Lu50', 'EuSo', 'Dniand', 'PROUDLY', 'SUPPORTING', 'OUR', "NATION'S", 'HEROES', 'THE', 'BEST', 'OF', 'WHAT', "WE'RE", 'MADE', 'OF', 'Jeep', 'u8o', 'HeernCEP', 'FUSO', 'Jeep', 'comOSR', 'Jeep', 'is', 'registered', 'trademark', 'of', 'Chrysler', 'Group', 'LLC', 'Jeep']
# Von spaCy erkannte Entitäten: {'ti 8ie oiui r16 aa cene wusd lu50', 'jeep', 'g6', 'pof', 'rh mz 1ehejj', 'oprah oprah klc mofh', 'saf retui waangler', 'heerncep fuso', 'chrysler group llc jeep', '4s'}
# Bereinigter Text ohne Sonderzeichen: ForTE iA FORTE Expected to be available Spring 2013 2014 Forte EX prototype with optional features shown FORTE KiD KIA For 87 Dra Jlzdluil Uu Mot attempt KID FORTE Da matizaden Donct attempl RESPECT the TECH AII New 2014 FOTE KIA
# Aufgeteilte Wörter (Kleinschreibung): ['ForTE', 'iA', 'FORTE', 'Expected', 'to', 'be', 'available', 'Spring', '2013', '2014', 'Forte', 'EX', 'prototype', 'with', 'optional', 'features', 'shown', 'FORTE', 'KiD', 'KIA', 'For', '87', 'Dra', 'Jlzdluil', 'Uu', 'Mot', 'attempt', 'KID', 'FORTE', 'Da', 'matizaden', 'Donct', 'attempl', 'RESPECT', 'the', 'TECH', 'AII', 'New', '2014', 'FOTE', 'KIA']
# Von spaCy erkannte Entitäten: {'forte', 'forte ia forte expected', 'dra jlzdluil', 'new 2014', '2014', '87', 'forte ex', 'kia'}
# Bereinigter Text ohne Sonderzeichen: C 1523 0ll Do not allerpl 7014 Sorenlo Expected Feb Z01S8 ed shown with optional features Expected Spring 2013 Closed course STOP Jiui 2 I3 USB Music UVO WHEELS ON The 8 J Wheels On The Bus_mp3 Menu List power Tune Dramatization Sequence shortened UVO commands vary by modeltrim phone Medin route 10 It has an answer for everything AII New 2014 SORENTO Built in the USA Assembled in the United States from US and globally sourced parts
# Aufgeteilte Wörter (Kleinschreibung): ['C', '1523', '0ll', 'Do', 'not', 'allerpl', '7014', 'Sorenlo', 'Expected', 'Feb', 'Z01S8', 'ed', 'shown', 'with', 'optional', 'features', 'Expected', 'Spring', '2013', 'Closed', 'course', 'STOP', 'Jiui', '2', 'I3', 'USB', 'Music', 'UVO', 'WHEELS', 'ON', 'The', '8', 'J', 'Wheels', 'On', 'The', 'Bus_mp3', 'Menu', 'List', 'power', 'Tune', 'Dramatization', 'Sequence', 'shortened', 'UVO', 'commands', 'vary', 'by', 'modeltrim', 'phone', 'Medin', 'route', '10', 'It', 'has', 'an', 'answer', 'for', 'everything', 'AII', 'New', '2014', 'SORENTO', 'Built', 'in', 'the', 'USA', 'Assembled', 'in', 'the', 'United', 'States', 'from', 'US', 'and', 'globally', 'sourced', 'parts']
# Von spaCy erkannte Entitäten: {'aii', '7014', '1523', 'spring 2013', 'the united states', 'uvo', 'new 2014 sorento built', 'us', '10', '8', 'medin'}
# Bereinigter Text ohne Sonderzeichen: Dramalization Do not altempl c   0 Avallable lealures shown Prolessional diiver on closed course MPG COMBINED EPA ESTIMATED Based on US EPA Greenhouse Gas Emissions and Energy Impact Scores 2013vs 2012 2013 MKZ Hybrid EPA estimated 45 cityl45 hwyl45 comrbined mpg Actual mileage wIl vary Awallable Terures shown Professional diver on closed course  ''0       INTPODUCING 7i  TV AV 1   CT  VT  UJ INTRODUCING THE LINCOLN MOTop COMPANY THE ALL New MKZ Linell cam
# Aufgeteilte Wörter (Kleinschreibung): ['Dramalization', 'Do', 'not', 'altempl', 'c', '0', 'Avallable', 'lealures', 'shown', 'Prolessional', 'diiver', 'on', 'closed', 'course', 'MPG', 'COMBINED', 'EPA', 'ESTIMATED', 'Based', 'on', 'US', 'EPA', 'Greenhouse', 'Gas', 'Emissions', 'and', 'Energy', 'Impact', 'Scores', '2013vs', '2012', '2013', 'MKZ', 'Hybrid', 'EPA', 'estimated', '45', 'cityl45', 'hwyl45', 'comrbined', 'mpg', 'Actual', 'mileage', 'wIl', 'vary', 'Awallable', 'Terures', 'shown', 'Professional', 'diver', 'on', 'closed', 'course', "''0", 'INTPODUCING', '7i', 'TV', 'AV', '1', 'CT', 'VT', 'UJ', 'INTRODUCING', 'THE', 'LINCOLN', 'MOTop', 'COMPANY', 'THE', 'ALL', 'New', 'MKZ', 'Linell', 'cam']
# Von spaCy erkannte Entitäten: {'vt  uj', 'epa greenhouse gas emissions', 'mpg combined epa estimated based', 'prolessional', 'av 1', 'mkz hybrid', 'the lincoln motop company', '2012 2013', 'epa', '7i', '45', 'awallable terures', 'ct', 'us'}
# Bereinigter Text ohne Sonderzeichen: THE LINCOLN MOTOR COMPANY HMMY FALLON PRESENT OTORConpa ARESENT Available features shown D M cptraFant Made In deanant JPLay Menu delete HIs0 Jnfo set Prod No 427o1 Wil Prodoror s MALOPie BE DI DAte DoldAaL day NIgHt Wkeaton PRODUCER DuOL ENA CMERA LD Za SALVEL Qoo WWWSTEER the SCRIPTcoM
# Aufgeteilte Wörter (Kleinschreibung): ['THE', 'LINCOLN', 'MOTOR', 'COMPANY', 'HMMY', 'FALLON', 'PRESENT', 'OTORConpa', 'ARESENT', 'Available', 'features', 'shown', 'D', 'M', 'cptraFant', 'Made', 'In', 'deanant', 'JPLay', 'Menu', 'delete', 'HIs0', 'Jnfo', 'set', 'Prod', 'No', '427o1', 'Wil', 'Prodoror', 's', 'MALOPie', 'BE', 'DI', 'DAte', 'DoldAaL', 'day', 'NIgHt', 'Wkeaton', 'PRODUCER', 'DuOL', 'ENA', 'CMERA', 'LD', 'Za', 'SALVEL', 'Qoo', 'WWWSTEER', 'the', 'SCRIPTcoM']
# Von spaCy erkannte Entitäten: {'d m cptrafant made', 'the lincoln motor company hmmy fallon present otorconpa', 'ena cmera', 'jplay menu', 'jnfo'}
# Bereinigter Text ohne Sonderzeichen: rated 2013 TM trademarks Incorporated 2013 Mars Ac Fresh chocolate's better with betterwithmms
# Aufgeteilte Wörter (Kleinschreibung): ['rated', '2013', 'TM', 'trademarks', 'Incorporated', '2013', 'Mars', 'Ac', 'Fresh', "chocolate's", 'better', 'with', 'betterwithmms']
# Von spaCy erkannte Entitäten: {'2013', 'betterwithmms'}
# Bereinigter Text ohne Sonderzeichen: Mio FIT NEW Mio FIT WITH ELECTROLYTES Always dilute ChangeStuff NEW Mto FIT Mio FIT liquID WDwaCeR ELECTRQ1TE5 B VITAMINS Bear 18 olast ChangeStuff
# Aufgeteilte Wörter (Kleinschreibung): ['Mio', 'FIT', 'NEW', 'Mio', 'FIT', 'WITH', 'ELECTROLYTES', 'Always', 'dilute', 'ChangeStuff', 'NEW', 'Mto', 'FIT', 'Mio', 'FIT', 'liquID', 'WDwaCeR', 'ELECTRQ1TE5', 'B', 'VITAMINS', 'Bear', '18', 'olast', 'ChangeStuff']
# Von spaCy erkannte Entitäten: {'changestuff', '18'}
# Bereinigter Text ohne Sonderzeichen: NETwonK ICT IVETwOnIt CIFL Netwonit Netwa PLATEn REGISTRATION PLATER Ecoistration NFL NfD couTido PATH T0 PRINETINE COMBINE 21loe 2013 40 ARD Uot ArNOun DASA WFV 2019 VerticAL JUMp JGOOD COMBIN JDEL 2013 013 INDIA NAPOLIS NFLcOM 21l65 21o8 2f5 Cok Naraonit CHIEFS dh Jaguars DEGd SAN Ynlk Uibe INv Qu DRAFT DRAFT Gnr 818 WD 2013 SANDCASTLE RA Su TOTTIN WFV SC 0UTIN G COMBINE 2013 2013 nfl comlprimetime WD SMIE BA
# Aufgeteilte Wörter (Kleinschreibung): ['NETwonK', 'ICT', 'IVETwOnIt', 'CIFL', 'Netwonit', 'Netwa', 'PLATEn', 'REGISTRATION', 'PLATER', 'Ecoistration', 'NFL', 'NfD', 'couTido', 'PATH', 'T0', 'PRINETINE', 'COMBINE', '21loe', '2013', '40', 'ARD', 'Uot', 'ArNOun', 'DASA', 'WFV', '2019', 'VerticAL', 'JUMp', 'JGOOD', 'COMBIN', 'JDEL', '2013', '013', 'INDIA', 'NAPOLIS', 'NFLcOM', '21l65', '21o8', '2f5', 'Cok', 'Naraonit', 'CHIEFS', 'dh', 'Jaguars', 'DEGd', 'SAN', 'Ynlk', 'Uibe', 'INv', 'Qu', 'DRAFT', 'DRAFT', 'Gnr', '818', 'WD', '2013', 'SANDCASTLE', 'RA', 'Su', 'TOTTIN', 'WFV', 'SC', '0UTIN', 'G', 'COMBINE', '2013', '2013', 'nfl', 'comlprimetime', 'WD', 'SMIE', 'BA']
# Von spaCy erkannte Entitäten: {'21l65', 'jgood combin', 'netwonk ict', 'smie ba', '2013 013', '2013 2013', 'wd', '21loe', 'cok', 'cifl netwonit netwa', 'gnr 818 wd', 'san ynlk uibe'}
# Bereinigter Text ohne Sonderzeichen: N5D USIAP 89 rcharoson 133 89 33 AIcWaRDSON richandSOK 22 VINCI EN J1 Stop STOP 21 93 PETERSON cIITIU PETERSON LararAL 93 Lampgel Pe TezeM 33 IIL Uw CAndinat 0d THANK YOU FOR BEING A FAN NFL_ NFLCOM
# Aufgeteilte Wörter (Kleinschreibung): ['N5D', 'USIAP', '89', 'rcharoson', '133', '89', '33', 'AIcWaRDSON', 'richandSOK', '22', 'VINCI', 'EN', 'J1', 'Stop', 'STOP', '21', '93', 'PETERSON', 'cIITIU', 'PETERSON', 'LararAL', '93', 'Lampgel', 'Pe', 'TezeM', '33', 'IIL', 'Uw', 'CAndinat', '0d', 'THANK', 'YOU', 'FOR', 'BEING', 'A', 'FAN', 'NFL_', 'NFLCOM']
# Von spaCy erkannte Entitäten: {'33', '133 89 33', 'nfl', '22', '93', 'iil uw', 'lampgel pe', 'vinci en', 'usiap', 'peterson'}
# Bereinigter Text ohne Sonderzeichen: Do not attempt Jp nol ahamot Ea Do Cal Cn Jab INFORMATION eouee  POL FFsa0sZ POL 56405z PoL WE  CHOOSE YOUR SIDE ON INSTAGRAM OREO ETHING DISAGREE
# Aufgeteilte Wörter (Kleinschreibung): ['Do', 'not', 'attempt', 'Jp', 'nol', 'ahamot', 'Ea', 'Do', 'Cal', 'Cn', 'Jab', 'INFORMATION', 'eouee', 'POL', 'FFsa0sZ', 'POL', '56405z', 'PoL', 'WE', 'CHOOSE', 'YOUR', 'SIDE', 'ON', 'INSTAGRAM', 'OREO', 'ETHING', 'DISAGREE']
# Von spaCy erkannte Entitäten: {'pol', '56405z', 'jp nol', 'ea'}
# Bereinigter Text ohne Sonderzeichen: MADE PEPSIHALFTIME ppeosi LIVE FOR Pfeoh Etla Meta LIVe Foahot Tuniste Aenin A4ueico PEPSI the Pepsi Globe and LIVE FOR NOW are rogistored trademarks of PepsiCo Inc 0 2013 PepsiCo Inc
# Aufgeteilte Wörter (Kleinschreibung): ['MADE', 'PEPSIHALFTIME', 'ppeosi', 'LIVE', 'FOR', 'Pfeoh', 'Etla', 'Meta', 'LIVe', 'Foahot', 'Tuniste', 'Aenin', 'A4ueico', 'PEPSI', 'the', 'Pepsi', 'Globe', 'and', 'LIVE', 'FOR', 'NOW', 'are', 'rogistored', 'trademarks', 'of', 'PepsiCo', 'Inc', '0', '2013', 'PepsiCo', 'Inc']
# Von spaCy erkannte Entitäten: {'pepsi', 'pepsico inc'}
# Bereinigter Text ohne Sonderzeichen: Do not attempt COLA ESS 14 Tastt Sugar Usie UGar next TS1 pepsi next First million it for FREE at PepsiNEXTcom 606 less sugar than Pepsi Cola PEPSI CULA PEPSI NEXT Ihe Pepsi Globe and DRINK IT TO BELIEVE IT are registered trademarks of PepsiCo Inc try
# Aufgeteilte Wörter (Kleinschreibung): ['Do', 'not', 'attempt', 'COLA', 'ESS', '14', 'Tastt', 'Sugar', 'Usie', 'UGar', 'next', 'TS1', 'pepsi', 'next', 'First', 'million', 'it', 'for', 'FREE', 'at', 'PepsiNEXTcom', '606', 'less', 'sugar', 'than', 'Pepsi', 'Cola', 'PEPSI', 'CULA', 'PEPSI', 'NEXT', 'Ihe', 'Pepsi', 'Globe', 'and', 'DRINK', 'IT', 'TO', 'BELIEVE', 'IT', 'are', 'registered', 'trademarks', 'of', 'PepsiCo', 'Inc', 'try']
# Von spaCy erkannte Entitäten: {'ts1 pepsi', 'ihe pepsi globe', 'pepsico inc', '606', 'pepsi cola pepsi', 'next first million', 'cola ess 14 tastt sugar usie'}
# Bereinigter Text ohne Sonderzeichen: Kny Kje 3 u Screen images simulated  Appearance of device may vary HU Glose Glose Smt Wuh LL 6 IS Accessory sold separately IcLO Uoool Icooe SamSUng SAMSUNO The Next Big Thing is Here
# Aufgeteilte Wörter (Kleinschreibung): ['Kny', 'Kje', '3', 'u', 'Screen', 'images', 'simulated', 'Appearance', 'of', 'device', 'may', 'vary', 'HU', 'Glose', 'Glose', 'Smt', 'Wuh', 'LL', '6', 'IS', 'Accessory', 'sold', 'separately', 'IcLO', 'Uoool', 'Icooe', 'SamSUng', 'SAMSUNO', 'The', 'Next', 'Big', 'Thing', 'is', 'Here']
# Von spaCy erkannte Entitäten: {'hu glose glose', 'accessory', 'the next big thing', 'kny kje 3', 'uoool icooe samsung samsuno'}
# Bereinigter Text ohne Sonderzeichen: skechers Gorune DESIGNED FOR SPEED
# Aufgeteilte Wörter (Kleinschreibung): ['skechers', 'Gorune', 'DESIGNED', 'FOR', 'SPEED']
# Von spaCy erkannte Entitäten: {'gorune'}
# Bereinigter Text ohne Sonderzeichen: 531149 sodasieam Source Euromonitor Packaging   Beverages Report USA 2012 AA sodastream sodastream com
# Aufgeteilte Wörter (Kleinschreibung): ['531149', 'sodasieam', 'Source', 'Euromonitor', 'Packaging', 'Beverages', 'Report', 'USA', '2012', 'AA', 'sodastream', 'sodastream', 'com']
# Von spaCy erkannte Entitäten: {'531149', 'source euromonitor packaging   ', '2012'}
# Bereinigter Text ohne Sonderzeichen: Onzrulti Ha Uchon Don't sweat it HANDLE ITS POwer Aresa Speed Ytick Ms AOIL HedOurtn HLeort Mhrd Outtt MLe Oee 7doutn L dOuttt
# Aufgeteilte Wörter (Kleinschreibung): ['Onzrulti', 'Ha', 'Uchon', "Don't", 'sweat', 'it', 'HANDLE', 'ITS', 'POwer', 'Aresa', 'Speed', 'Ytick', 'Ms', 'AOIL', 'HedOurtn', 'HLeort', 'Mhrd', 'Outtt', 'MLe', 'Oee', '7doutn', 'L', 'dOuttt']
# Von spaCy erkannte Entitäten: {'douttt', 'hleort mhrd outtt mle oee 7doutn l'}
# Bereinigter Text ohne Sonderzeichen: eile Mkeneg Emes WEE nnn Subwar Arc Oi Arac SUBWAr rices and participation may vary Plus tax where applicable Excludes Supreme Subs Additional charge for Extras Prices higher in Alaska and Hawai S5 02013 Doctor's Associates Inc SUBWAY is a registered trademark of Doctor s Associates Inc Fooioncs IEET SUBWAY way com bruANY Mice fresh eat
# Aufgeteilte Wörter (Kleinschreibung): ['eile', 'Mkeneg', 'Emes', 'WEE', 'nnn', 'Subwar', 'Arc', 'Oi', 'Arac', 'SUBWAr', 'rices', 'and', 'participation', 'may', 'vary', 'Plus', 'tax', 'where', 'applicable', 'Excludes', 'Supreme', 'Subs', 'Additional', 'charge', 'for', 'Extras', 'Prices', 'higher', 'in', 'Alaska', 'and', 'Hawai', 'S5', '02013', "Doctor's", 'Associates', 'Inc', 'SUBWAY', 'is', 'a', 'registered', 'trademark', 'of', 'Doctor', 's', 'Associates', 'Inc', 'Fooioncs', 'IEET', 'SUBWAY', 'way', 'com', 'bruANY', 'Mice', 'fresh', 'eat']
# Von spaCy erkannte Entitäten: {'alaska', 'hawai s5 02013', 'associates inc subway', 'doctor s associates inc fooioncs', 'bruany mice', 'nnn subwar arc oi arac', 'mkeneg emes'}
# Bereinigter Text ohne Sonderzeichen: Ja0 02013 Doctor s Associates Inc SUBWAY isa registered trademark of Doctor s Associates Inc SUBWAY FRESH FIT is not a diet program citan SUBWAY CCd Tasnt Afac Joodnar 15 Aex afresa MT SUBWAY subway COf LSyr WirJnlingStreak Results nottypical Ask your doctor before beginning any weight loss plan d lost weightand Is keeping it oNf with the help of exercise and low  fat SUBWAY subs ftesh eat
# Aufgeteilte Wörter (Kleinschreibung): ['Ja0', '02013', 'Doctor', 's', 'Associates', 'Inc', 'SUBWAY', 'isa', 'registered', 'trademark', 'of', 'Doctor', 's', 'Associates', 'Inc', 'SUBWAY', 'FRESH', 'FIT', 'is', 'not', 'a', 'diet', 'program', 'citan', 'SUBWAY', 'CCd', 'Tasnt', 'Afac', 'Joodnar', '15', 'Aex', 'afresa', 'MT', 'SUBWAY', 'subway', 'COf', 'LSyr', 'WirJnlingStreak', 'Results', 'nottypical', 'Ask', 'your', 'doctor', 'before', 'beginning', 'any', 'weight', 'loss', 'plan', 'd', 'lost', 'weightand', 'Is', 'keeping', 'it', 'oNf', 'with', 'the', 'help', 'of', 'exercise', 'and', 'low', 'fat', 'SUBWAY', 'subs', 'ftesh', 'eat']
# Von spaCy erkannte Entitäten: {'subway', '15', '02013', 'mt subway', 'aex', 'doctor s associates inc subway fresh fit', 'ccd'}
# Bereinigter Text ohne Sonderzeichen: 4d 4ai 41s GLENCOBROOKE RETIREMENT HOME 41427 WELG Top Juobi Tp3 AwMIO HohUI ZHT Tp3 Z1HT MnnId Md HJVUI ZPCE0BG i  Iaco ZPCE086 iL JAcOE han 0 T  0 PoLICE 62467 GLENCOBRO RETIREMEN 44z7 TACO belL Live MAs facebook comtacobell
# Aufgeteilte Wörter (Kleinschreibung): ['4d', '4ai', '41s', 'GLENCOBROOKE', 'RETIREMENT', 'HOME', '41427', 'WELG', 'Top', 'Juobi', 'Tp3', 'AwMIO', 'HohUI', 'ZHT', 'Tp3', 'Z1HT', 'MnnId', 'Md', 'HJVUI', 'ZPCE0BG', 'i', 'Iaco', 'ZPCE086', 'iL', 'JAcOE', 'han', '0', 'T', '0', 'PoLICE', '62467', 'GLENCOBRO', 'RETIREMEN', '44z7', 'TACO', 'belL', 'Live', 'MAs', 'facebook', 'comtacobell']
# Von spaCy erkannte Entitäten: {'44z7', '41427', 'md hjvui zpce0bg', 'han', '4ai', 'iaco', 'taco', '4d'}
# Bereinigter Text ohne Sonderzeichen: 49ut 49ERS NFi 49XF NFL Ed Jan7 Me 495n7 fde NO STAIN IS SACRED MIRACLESTAIN MIRACLESTAIN COM 16 16 16 Staln F Mucaci Cach Stalh  dit I3 bxa I39 Libuu B3S cudoa cund Wd CAUTIOa CauTIOH Cumn A9Er 1628 49117 421F RANCISCO FRANCISCO 49382 Da SM WITNESSED MMON NONTINALAND JOYTANAL 4L MDM 9E6 6DM Uut 44M fde
# Aufgeteilte Wörter (Kleinschreibung): ['49ut', '49ERS', 'NFi', '49XF', 'NFL', 'Ed', 'Jan7', 'Me', '495n7', 'fde', 'NO', 'STAIN', 'IS', 'SACRED', 'MIRACLESTAIN', 'MIRACLESTAIN', 'COM', '16', '16', '16', 'Staln', 'F', 'Mucaci', 'Cach', 'Stalh', 'dit', 'I3', 'bxa', 'I39', 'Libuu', 'B3S', 'cudoa', 'cund', 'Wd', 'CAUTIOa', 'CauTIOH', 'Cumn', 'A9Er', '1628', '49117', '421F', 'RANCISCO', 'FRANCISCO', '49382', 'Da', 'SM', 'WITNESSED', 'MMON', 'NONTINALAND', 'JOYTANAL', '4L', 'MDM', '9E6', '6DM', 'Uut', '44M', 'fde']
# Von spaCy erkannte Entitäten: {'uut 44m fde', 'i39 libuu', '495n7', 'cautioh cumn a9er', '49382', 'nfl', 'wd', '16', '1628 49117', '16 16', 'rancisco francisco'}
# Bereinigter Text ohne Sonderzeichen: Prototype with aptions Exterior spare not available tire Sirius XM Radio Inc Simulated screen shown Al Aypio Siriuskm Off OSirius XM Radio Inc Simulated screen shown E G Aadio Satelle HTRACK taAn oJAaNlo Haet ETOn K F'euulia inulate Goon ses WishGranted
# Aufgeteilte Wörter (Kleinschreibung): ['Prototype', 'with', 'aptions', 'Exterior', 'spare', 'not', 'available', 'tire', 'Sirius', 'XM', 'Radio', 'Inc', 'Simulated', 'screen', 'shown', 'Al', 'Aypio', 'Siriuskm', 'Off', 'OSirius', 'XM', 'Radio', 'Inc', 'Simulated', 'screen', 'shown', 'E', 'G', 'Aadio', 'Satelle', 'HTRACK', 'taAn', 'oJAaNlo', 'Haet', 'ETOn', 'K', "F'euulia", 'inulate', 'Goon', 'ses', 'WishGranted']
# Von spaCy erkannte Entitäten: {'sirius xm radio inc simulated', "k f'euulia", 'al aypio siriuskm off', 'osirius xm radio inc simulated', 'goon', 'exterior'}
# Bereinigter Text ohne Sonderzeichen: LDY Good Vibes onne Fcouan QJN Get in Get happy Ht6J844 Get in Get happy HT6Jba4 Das Aulos Das Auto GetHappy
# Aufgeteilte Wörter (Kleinschreibung): ['LDY', 'Good', 'Vibes', 'onne', 'Fcouan', 'QJN', 'Get', 'in', 'Get', 'happy', 'Ht6J844', 'Get', 'in', 'Get', 'happy', 'HT6Jba4', 'Das', 'Aulos', 'Das', 'Auto', 'GetHappy']
# Von spaCy erkannte Entitäten: {'ht6j844 get', 'get happy ht6jba4 das aulos das auto gethappy'}
# Bereinigter Text ohne Sonderzeichen: Gs  cS  Healthy Snackin CrackinStyle
# Aufgeteilte Wörter (Kleinschreibung): ['Gs', 'cS', 'Healthy', 'Snackin', 'CrackinStyle']
# Von spaCy erkannte Entitäten: {'healthy snackin crackinstyle'}
# Bereinigter Text ohne Sonderzeichen: LlopaDLlplelo LEnILLLLL Lo 4 SEELILLzl 3ll5l4LLl Lulull LEEDdill L Lo YOUR DREAM IS OUT THERE GO GET IT AMERICAN FAMILY INSURANCE WE LL PROTECT IT AMERICAN FAMILY INSURANCE longlivedreams Ia rtarargphraceWr 6u33an7eaPan3 Uusm W Sur Me kuena 95 bep
# Aufgeteilte Wörter (Kleinschreibung): ['LlopaDLlplelo', 'LEnILLLLL', 'Lo', '4', 'SEELILLzl', '3ll5l4LLl', 'Lulull', 'LEEDdill', 'L', 'Lo', 'YOUR', 'DREAM', 'IS', 'OUT', 'THERE', 'GO', 'GET', 'IT', 'AMERICAN', 'FAMILY', 'INSURANCE', 'WE', 'LL', 'PROTECT', 'IT', 'AMERICAN', 'FAMILY', 'INSURANCE', 'longlivedreams', 'Ia', 'rtarargphraceWr', '6u33an7eaPan3', 'Uusm', 'W', 'Sur', 'Me', 'kuena', '95', 'bep']
# Von spaCy erkannte Entitäten: {'ia', '95', 'american family', '4', '6u33an7eapan3', 'lulull leeddill l lo'}
# Bereinigter Text ohne Sonderzeichen: QJAYTJ PEtYARD 106 Valet ALL antT Wite Viom BRLTD Logan HILLS CENNEL CLlun DOG show 4M LOo HLLS KENNEL CLUB DOG ShOW WB Smow Flal OD Prolesslonal diver  Closed course Do not altempt DOLD SARAH M LIV Ja TYI TYI JUL 2MDA20  Compromise scares us too WH Aa CIL CSD Eenda ANIMAL RESCUE 2501 19 wheels shown delayed availability The all new Audi A3_ Designed without compromise udl Truth in Engineering StayUncompromised
# Aufgeteilte Wörter (Kleinschreibung): ['QJAYTJ', 'PEtYARD', '106', 'Valet', 'ALL', 'antT', 'Wite', 'Viom', 'BRLTD', 'Logan', 'HILLS', 'CENNEL', 'CLlun', 'DOG', 'show', '4M', 'LOo', 'HLLS', 'KENNEL', 'CLUB', 'DOG', 'ShOW', 'WB', 'Smow', 'Flal', 'OD', 'Prolesslonal', 'diver', 'Closed', 'course', 'Do', 'not', 'altempt', 'DOLD', 'SARAH', 'M', 'LIV', 'Ja', 'TYI', 'TYI', 'JUL', '2MDA20', 'Compromise', 'scares', 'us', 'too', 'WH', 'Aa', 'CIL', 'CSD', 'Eenda', 'ANIMAL', 'RESCUE', '2501', '19', 'wheels', 'shown', 'delayed', 'availability', 'The', 'all', 'new', 'Audi', 'A3_', 'Designed', 'without', 'compromise', 'udl', 'Truth', 'in', 'Engineering', 'StayUncompromised']
# Von spaCy erkannte Entitäten: {'dold sarah m', 'udl truth', '106', 'valet', 'wite', 'liv ja tyi tyi', 'wb smow flal', '4m', 'qjaytj', 'audi', '2mda20', 'wh aa cil csd eenda', '2501 19'}
# Bereinigter Text ohne Sonderzeichen: DEB 2339 PEACE ONE DAY Suppori PeacE ONe DAY KIssFORPEACE
# Aufgeteilte Wörter (Kleinschreibung): ['DEB', '2339', 'PEACE', 'ONE', 'DAY', 'Suppori', 'PeacE', 'ONe', 'DAY', 'KIssFORPEACE']
# Von spaCy erkannte Entitäten: {'deb', 'one'}
# Bereinigter Text ohne Sonderzeichen: IN SUPPORT OF RED FOR THE NEXT 24 HOURS U2 INVISIBLE FREE on iTunes Fo Ecn l 52 DonrJQu LNds veoohi FREE on iTunes VEuud Ou Loipoyhue IueacWuL Lull ide Wuu FREE on iTunes Id siu3t USi o D04 Baucu Hd Lnnrahon Maset 52000 OOOide Frund 0 JHadS Requrds Juue 3 Elouc onp dun ed je uesaciunL Conleld SL2 harle JeLb cunilis FREE on iTunes Kr Kueduns II Ba Ljte Mlo 6S206u U624un Ustud Le Cug  Fund THIYMUS Requezs Uxuil oec_Rtlnzd Ius Cune suctlaawale hj Ie3le 62 ddiboIs appl FRFF on iTunes For Cuumt Jouu54 LESI O EIZWI L Iaawnaropn W Hki Iplo 6S2ono qul nuTEsue uunhoguueu Htoneunr TWS_eSL ue duesaowunL Com 5217 Davar Ily Ieste s a dados aph FOR EVERY DOWNLOAD BANK OF AMERICA DONATES 51 TO RED For eved Obunkced unb 41597 ESTon 232014 Bank ol eenca Comaration will donale SL Ip Yo 52000 000Uothe US Fur  Ioz W Glb3Fund o 65ol HIYADS  Requires Tun 5 account ole duktuad pet nesac ount Conlent suicl baautimy ins tents 2nd condilions apply RED Bank ot Amenca CONNECTARE Nca and Meliena ol Lnencae0 wc neuulotd Bacemoaks O Baa o Aaendt Dpua Jensze Ue Valemaks d Iheu nescne derer5aniae lenperesin  7014054 Waw RED Bankt al America CONNECTARED oua Ua 0f Vope  J0 are Tegotaed 15L9 0El OF Amenca Caapuleuogog sheIbe tene 0 2010
# Aufgeteilte Wörter (Kleinschreibung): ['IN', 'SUPPORT', 'OF', 'RED', 'FOR', 'THE', 'NEXT', '24', 'HOURS', 'U2', 'INVISIBLE', 'FREE', 'on', 'iTunes', 'Fo', 'Ecn', 'l', '52', 'DonrJQu', 'LNds', 'veoohi', 'FREE', 'on', 'iTunes', 'VEuud', 'Ou', 'Loipoyhue', 'IueacWuL', 'Lull', 'ide', 'Wuu', 'FREE', 'on', 'iTunes', 'Id', 'siu3t', 'USi', 'o', 'D04', 'Baucu', 'Hd', 'Lnnrahon', 'Maset', '52000', 'OOOide', 'Frund', '0', 'JHadS', 'Requrds', 'Juue', '3', 'Elouc', 'onp', 'dun', 'ed', 'je', 'uesaciunL', 'Conleld', 'SL2', 'harle', 'JeLb', 'cunilis', 'FREE', 'on', 'iTunes', 'Kr', 'Kueduns', 'II', 'Ba', 'Ljte', 'Mlo', '6S206u', 'U624un', 'Ustud', 'Le', 'Cug', 'Fund', 'THIYMUS', 'Requezs', 'Uxuil', 'oec_Rtlnzd', 'Ius', 'Cune', 'suctlaawale', 'hj', 'Ie3le', '62', 'ddiboIs', 'appl', 'FRFF', 'on', 'iTunes', 'For', 'Cuumt', 'Jouu54', 'LESI', 'O', 'EIZWI', 'L', 'Iaawnaropn', 'W', 'Hki', 'Iplo', '6S2ono', 'qul', 'nuTEsue', 'uunhoguueu', 'Htoneunr', 'TWS_eSL', 'ue', 'duesaowunL', 'Com', '5217', 'Davar', 'Ily', 'Ieste', 's', 'a', 'dados', 'aph', 'FOR', 'EVERY', 'DOWNLOAD', 'BANK', 'OF', 'AMERICA', 'DONATES', '51', 'TO', 'RED', 'For', 'eved', 'Obunkced', 'unb', '41597', 'ESTon', '232014', 'Bank', 'ol', 'eenca', 'Comaration', 'will', 'donale', 'SL', 'Ip', 'Yo', '52000', '000Uothe', 'US', 'Fur', 'Ioz', 'W', 'Glb3Fund', 'o', '65ol', 'HIYADS', 'Requires', 'Tun', '5', 'account', 'ole', 'duktuad', 'pet', 'nesac', 'ount', 'Conlent', 'suicl', 'baautimy', 'ins', 'tents', '2nd', 'condilions', 'apply', 'RED', 'Bank', 'ot', 'Amenca', 'CONNECTARE', 'Nca', 'and', 'Meliena', 'ol', 'Lnencae0', 'wc', 'neuulotd', 'Bacemoaks', 'O', 'Baa', 'o', 'Aaendt', 'Dpua', 'Jensze', 'Ue', 'Valemaks', 'd', 'Iheu', 'nescne', 'derer5aniae', 'lenperesin', '7014054', 'Waw', 'RED', 'Bankt', 'al', 'America', 'CONNECTARED', 'oua', 'Ua', '0f', 'Vope', 'J0', 'are', 'Tegotaed', '15L9', '0El', 'OF', 'Amenca', 'Caapuleuogog', 'sheIbe', 'tene', '0', '2010']
# Von spaCy erkannte Entitäten: {'itunes kr kueduns ii ba', 'conlent suicl baautimy ins', 'd04', 'meliena', '6s206u', '0 2010', 'amenca caapuleuogog', 'ole', 'the next 24 hours u2', 'derer5aniae lenperesin', 'hiyads  requires tun 5', 'tegotaed', 'itunes', 'us', '7014054', '52000', 'htoneunr', 'comaration', 'bank of america', 'ioz w', 'o 65ol', 'donale sl ip yo 52000', '0f', 'bank', 'ius cune', 'red bank', '41597', 'itunes veuud', 'elouc onp dun ed je uesaciunl conleld', 'requezs uxuil', '51', '232014', 'dpua jensze ue', 'cuumt jouu54 lesi'}
# Bereinigter Text ohne Sonderzeichen: LVccds IHe Woods Kecle Ire Kppe Kooa d Frone a etrademats  AcoleIcc  Feguste fl In Kna U S and orer ountries Aio Sireisa Uo MuIkeaouic LUl Ea Euti Ea Data Fta Dat hosriiatonl Alor pLacC YoU DO This  Your spirit S1499mo FOR A FAMILY OF 5 MhusIC atat Appstore baaocortrequ Sea al o abealsrusc  delalls 0aa Iaes Iaves eskricucns May appl Cancel anpting
# ...
# Von spaCy erkannte Entitäten: {'ineraneeale jcoumallon', '47', 'ri', 'uc', '1o50', '74 040', 'kongau', 'rarael conanct', '2o00', 'ums nh uauueutwulnhrantinwu etl', '23371', 'wpout diicen', '7077a', 'ni na iny', 'wkice ikeueehom', '17n4', '020zoyo ca lk', '14z0', 'uneed', 'dult', 'fanaed ucntigl orianaj', 'lecahi 3010', '50', '7676', 'deteoll', 'universe', '2413', 'teunio', 'ranie nys', 'carl house', 'watle', 'rocket rocket homes mortgage official mortgage provider', 'ruleiamtuauc uc nmls', 'moilgege', 'colc fitions mny', 'ajicoticn ms', 'foamu ct', 'keutet hoilgau', 'cket', 'donnlond yout', 'onlya fate', '100157357', 'moiig', 'uoan compdx lcelec', '5225', '3020', '4uridledun', 'roc', 'munlatcmi cai aela miu deu hiol puly', 'uenecu weentel', 'matu', 'ny rurke mulg j  c', 'malibu ca umages', 'calitc  dre 301804478', 'ar tx', 'maeri rocket hores', '4097n', 'oiriatinj', '07022', 'wutxinaid ae oelrnt', 'ror tethones vli', 'vce', 'ueue nolan', 'rru tdt hone real estate uic', 'ritet moilg j  anu raaiei houe', 'putc mutg je', '52250', '48276', '31020', 'mra', '48776', 'rocket approvall', '6i 00', 'houo lcuet ukente'}
# Bereinigter Text ohne Sonderzeichen: Blazes Trail Toom Tn Llloi s UTTER sutter Jodmn JTeam salesforce
# Aufgeteilte Wörter (Kleinschreibung): ['Blazes', 'Trail', 'Toom', 'Tn', 'Llloi', 's', 'UTTER', 'sutter', 'Jodmn', 'JTeam', 'salesforce']
# Von spaCy erkannte Entitäten: {'jodmn jteam', 'blazes trail toom tn'}
# Bereinigter Text ohne Sonderzeichen: Omy at Sam  Club Member  Mark sams club DLDIR DuLar 5590 Mancu AOrin SCAN  GO PURCHASED 0505 Luotlelo 159525 Er 1p525 Hulll 5050 Kt Holc 525 505 To sum's club Dairy I0 0 to 0 DEF VLOTF VOH beef  bieT VIC Ot we om betF VUOTH vilI beef bac HLOH beet  Fopw Scan  Go_ Scan  Go Just like Kevin only at sam's club
# Aufgeteilte Wörter (Kleinschreibung): ['Omy', 'at', 'Sam', 'Club', 'Member', 'Mark', 'sams', 'club', 'DLDIR', 'DuLar', '5590', 'Mancu', 'AOrin', 'SCAN', 'GO', 'PURCHASED', '0505', 'Luotlelo', '159525', 'Er', '1p525', 'Hulll', '5050', 'Kt', 'Holc', '525', '505', 'To', "sum's", 'club', 'Dairy', 'I0', '0', 'to', '0', 'DEF', 'VLOTF', 'VOH', 'beef', 'bieT', 'VIC', 'Ot', 'we', 'om', 'betF', 'VUOTH', 'vilI', 'beef', 'bac', 'HLOH', 'beet', 'Fopw', 'Scan', 'Go_', 'Scan', 'Go', 'Just', 'like', 'Kevin', 'only', 'at', "sam's", 'club']
# Von spaCy erkannte Entitäten: {'dldir dular', '0505', 'vuoth', 'mark sams', 'sam  club', "sam's", '1p525', '5590 mancu aorin', 'luotlelo 159525', 'voh', 'fopw scan', 'bac hloh beet', 'kevin', '505', 'vic ot', 'dairy i0 0'}
# Bereinigter Text ohne Sonderzeichen: SLE SIIELLS SALLYS Shop Now SEASHEL Dorow Shop  Shells Qalod Shclls Shop E Shells Liom Spiny Conch _ 67 Great Scallop S Shop S Shells BUXNOW Queen Conch Shells Great Scallop Shells Spiny Conch Shells WILox BUYNOW Pearlf Shells Shells Sop  Shop  Shop  Shopf Frehbing  Conch 5 Shells Shop E Nautilus  Shop C Common  enom Whelk  BUX NOW Su 20 159 sec Ao 228 S6c Pcc puc Du SQUARESPACE EVERYTHING TO SCLL ANYTHING Ug
# Aufgeteilte Wörter (Kleinschreibung): ['SLE', 'SIIELLS', 'SALLYS', 'Shop', 'Now', 'SEASHEL', 'Dorow', 'Shop', 'Shells', 'Qalod', 'Shclls', 'Shop', 'E', 'Shells', 'Liom', 'Spiny', 'Conch', '_', '67', 'Great', 'Scallop', 'S', 'Shop', 'S', 'Shells', 'BUXNOW', 'Queen', 'Conch', 'Shells', 'Great', 'Scallop', 'Shells', 'Spiny', 'Conch', 'Shells', 'WILox', 'BUYNOW', 'Pearlf', 'Shells', 'Shells', 'Sop', 'Shop', 'Shop', 'Shopf', 'Frehbing', 'Conch', '5', 'Shells', 'Shop', 'E', 'Nautilus', 'Shop', 'C', 'Common', 'enom', 'Whelk', 'BUX', 'NOW', 'Su', '20', '159', 'sec', 'Ao', '228', 'S6c', 'Pcc', 'puc', 'Du', 'SQUARESPACE', 'EVERYTHING', 'TO', 'SCLL', 'ANYTHING', 'Ug']
# Von spaCy erkannte Entitäten: {'pcc puc du squarespace', '67', 'great scallop s', 'sle siiells sallys shop', 'sec', 'shopf frehbing', 'conch 5 shells', 'shop  shop', 'whelk  bux'}
# Bereinigter Text ohne Sonderzeichen: CLOWNUS CONFORMUS Do Not Altempl Do Not Attempt 6ir Fci FIREL Lie Mkc Etf Eco TACO BELL BuRGEAS 02022 Taco Bell IP Hdder LLC
# Aufgeteilte Wörter (Kleinschreibung): ['CLOWNUS', 'CONFORMUS', 'Do', 'Not', 'Altempl', 'Do', 'Not', 'Attempt', '6ir', 'Fci', 'FIREL', 'Lie', 'Mkc', 'Etf', 'Eco', 'TACO', 'BELL', 'BuRGEAS', '02022', 'Taco', 'Bell', 'IP', 'Hdder', 'LLC']
# Von spaCy erkannte Entitäten: {'taco bell ip hdder', 'mkc etf eco', '02022'}
# Bereinigter Text ohne Sonderzeichen: ton vIJR VERIZON PHONE DESERVES RE 5G BARS IN MORE PLACES T Mobile has America s largest 5G network See 5G device coverage  access details at T Mobile com Ler ACT NOW CUE YOUR ATT PHONE TODAY CTNOV CUE YucenT PHONE TODAY VPSG 508  HONES 4iltsG DOIt FOR THE PHONES To be contin
# Aufgeteilte Wörter (Kleinschreibung): ['ton', 'vIJR', 'VERIZON', 'PHONE', 'DESERVES', 'RE', '5G', 'BARS', 'IN', 'MORE', 'PLACES', 'T', 'Mobile', 'has', 'America', 's', 'largest', '5G', 'network', 'See', '5G', 'device', 'coverage', 'access', 'details', 'at', 'T', 'Mobile', 'com', 'Ler', 'ACT', 'NOW', 'CUE', 'YOUR', 'ATT', 'PHONE', 'TODAY', 'CTNOV', 'CUE', 'YucenT', 'PHONE', 'TODAY', 'VPSG', '508', 'HONES', '4iltsG', 'DOIt', 'FOR', 'THE', 'PHONES', 'To', 'be', 'contin']
# Von spaCy erkannte Entitäten: {'5', '4iltsg', 'ler', 'america', '508'}
# Bereinigter Text ohne Sonderzeichen: INTERMET BILl 558 elll Terez onal FCC Rate Benchmark SAVE UPTO 50 SGHOMEA INTERNET INTRODUCING T MOBILE HOME INTERNET 5G HOME IT INTERNET HECK AVAILABILITY T MOBILE COMAWIFI Available t0 many households in most US cities and towns Details at T Mobile com WiFI
# Aufgeteilte Wörter (Kleinschreibung): ['INTERMET', 'BILl', '558', 'elll', 'Terez', 'onal', 'FCC', 'Rate', 'Benchmark', 'SAVE', 'UPTO', '50', 'SGHOMEA', 'INTERNET', 'INTRODUCING', 'T', 'MOBILE', 'HOME', 'INTERNET', '5G', 'HOME', 'IT', 'INTERNET', 'HECK', 'AVAILABILITY', 'T', 'MOBILE', 'COMAWIFI', 'Available', 't0', 'many', 'households', 'in', 'most', 'US', 'cities', 'and', 'towns', 'Details', 'at', 'T', 'Mobile', 'com', 'WiFI']
# Von spaCy erkannte Entitäten: {'intermet', 'us', '50', 'terez onal fcc rate benchmark', '558', '5', 'sghomea'}
# Bereinigter Text ohne Sonderzeichen: Miley IDa Crka Phones ZA Cyrus 5G PHONES NEED YOUR HELP 30 ITFOR HE PHOt PHO FMobile verizonv SGe8Vo3E SG88Wore COVERAGE verizon TMobile 5632 SGew9ce SCUE YOUR SG PHONE TODAY mnKlejm Jcdsg Il 3 SCUE YOUR 5G PHONE TODAY Based on median overall combined SG speeds according to analysis by Ookla of Speedtest Intelligence data 5G download speeds for 04 2021 See SG device coverage  access details VOUR 5G PHGNETAD  Ho JTsG DO nT Fe THEF dltsG IEAR MORE FROM MILEY At T MOBILECOM Fok PHONE
# Aufgeteilte Wörter (Kleinschreibung): ['Miley', 'IDa', 'Crka', 'Phones', 'ZA', 'Cyrus', '5G', 'PHONES', 'NEED', 'YOUR', 'HELP', '30', 'ITFOR', 'HE', 'PHOt', 'PHO', 'FMobile', 'verizonv', 'SGe8Vo3E', 'SG88Wore', 'COVERAGE', 'verizon', 'TMobile', '5632', 'SGew9ce', 'SCUE', 'YOUR', 'SG', 'PHONE', 'TODAY', 'mnKlejm', 'Jcdsg', 'Il', '3', 'SCUE', 'YOUR', '5G', 'PHONE', 'TODAY', 'Based', 'on', 'median', 'overall', 'combined', 'SG', 'speeds', 'according', 'to', 'analysis', 'by', 'Ookla', 'of', 'Speedtest', 'Intelligence', 'data', '5G', 'download', 'speeds', 'for', '04', '2021', 'See', 'SG', 'device', 'coverage', 'access', 'details', 'VOUR', '5G', 'PHGNETAD', 'Ho', 'JTsG', 'DO', 'nT', 'Fe', 'THEF', 'dltsG', 'IEAR', 'MORE', 'FROM', 'MILEY', 'At', 'T', 'MOBILECOM', 'Fok', 'PHONE']
# Von spaCy erkannte Entitäten: {'za cyrus 5', '5632', 'sg88wore', 'vour', 'ho jtsg', 'sg', 'scue', '04 2021', '5', 'verizon', 'speedtest intelligence', 'miley', 'jcdsg il 3', '30'}
# Bereinigter Text ohne Sonderzeichen: IOC  GREENSPAN Bud  CTV Tolovision Network Lid Productions Inc AIl rights roserved Cappy 4 k After Brian lost his eyesight the McKeever brothers went on to win 10 Paralympic medals START YOUR IMPOSSIBLE TOYOTA TOYOTA Worldwide Wordidd Olympie Partner Paralympic Partner TOYOTA worldwide Worldiide Olympic Partner Paralympie Partncr
# Aufgeteilte Wörter (Kleinschreibung): ['IOC', 'GREENSPAN', 'Bud', 'CTV', 'Tolovision', 'Network', 'Lid', 'Productions', 'Inc', 'AIl', 'rights', 'roserved', 'Cappy', '4', 'k', 'After', 'Brian', 'lost', 'his', 'eyesight', 'the', 'McKeever', 'brothers', 'went', 'on', 'to', 'win', '10', 'Paralympic', 'medals', 'START', 'YOUR', 'IMPOSSIBLE', 'TOYOTA', 'TOYOTA', 'Worldwide', 'Wordidd', 'Olympie', 'Partner', 'Paralympic', 'Partner', 'TOYOTA', 'worldwide', 'Worldiide', 'Olympic', 'Partner', 'Paralympie', 'Partncr']
# Von spaCy erkannte Entitäten: {'greenspan bud  ', 'ioc', 'paralympic', 'toyota', 'brian', 'tolovision network lid productions inc', '4', '10', 'mckeever', 'worldiide olympic partner'}
# Bereinigter Text ohne Sonderzeichen: TRD Pro model available spring 2022 TUNDRA TRDCRO MIJONES IJONES Closed course Do not attempt TOYOTA Off roading is inherently dangerous Abusive use may result In bodily harm or vehicle damage Wear seatbelts at all limes and do not allow passengers In cargo area PAsS PROCEED ATc YOUR OWN RISK JONES IJONES THE ALL NEW TUNDRA EORA TUNDRA
# Aufgeteilte Wörter (Kleinschreibung): ['TRD', 'Pro', 'model', 'available', 'spring', '2022', 'TUNDRA', 'TRDCRO', 'MIJONES', 'IJONES', 'Closed', 'course', 'Do', 'not', 'attempt', 'TOYOTA', 'Off', 'roading', 'is', 'inherently', 'dangerous', 'Abusive', 'use', 'may', 'result', 'In', 'bodily', 'harm', 'or', 'vehicle', 'damage', 'Wear', 'seatbelts', 'at', 'all', 'limes', 'and', 'do', 'not', 'allow', 'passengers', 'In', 'cargo', 'area', 'PAsS', 'PROCEED', 'ATc', 'YOUR', 'OWN', 'RISK', 'JONES', 'IJONES', 'THE', 'ALL', 'NEW', 'TUNDRA', 'EORA', 'TUNDRA']
# Von spaCy erkannte Entitäten: {'2022', 'jones', 'toyota', 'wear'}
# Bereinigter Text ohne Sonderzeichen: ERPIRI 7o Wi Ta Bada We'Re DOWN To FARTH EIae EMie intuit turbotax
# Aufgeteilte Wörter (Kleinschreibung): ['ERPIRI', '7o', 'Wi', 'Ta', 'Bada', "We'Re", 'DOWN', 'To', 'FARTH', 'EIae', 'EMie', 'intuit', 'turbotax']
# Von spaCy erkannte Entitäten: {'7o', 'erpiri', 'intuit', 'wi ta bada'}
# Bereinigter Text ohne Sonderzeichen: WE CONNECT MORE COUNTRIES THAN ANY OTHER AIRLINE A STAR ALLIANCE Member TURKISH AIRLINES
# Aufgeteilte Wörter (Kleinschreibung): ['WE', 'CONNECT', 'MORE', 'COUNTRIES', 'THAN', 'ANY', 'OTHER', 'AIRLINE', 'A', 'STAR', 'ALLIANCE', 'Member', 'TURKISH', 'AIRLINES']
# Von spaCy erkannte Entitäten: {'turkish airlines', 'star alliance'}
# Bereinigter Text ohne Sonderzeichen: Uber Eats Alurminum Foit Om Foil tn Prop food Do not eat dish soap Uber Candle available in NYC and LA only Uber Kitty Litter Prop food Donoteat kitty Hopey Toasted hnclies itter Now delivering Eats And Dont Eats Uber Eats PURI Donot actually eat anyof the items shown Item availability varies by market Other restrictions may apply See app for details Dan ad Ot Dos FOOD ARKLAN
# Aufgeteilte Wörter (Kleinschreibung): ['Uber', 'Eats', 'Alurminum', 'Foit', 'Om', 'Foil', 'tn', 'Prop', 'food', 'Do', 'not', 'eat', 'dish', 'soap', 'Uber', 'Candle', 'available', 'in', 'NYC', 'and', 'LA', 'only', 'Uber', 'Kitty', 'Litter', 'Prop', 'food', 'Donoteat', 'kitty', 'Hopey', 'Toasted', 'hnclies', 'itter', 'Now', 'delivering', 'Eats', 'And', 'Dont', 'Eats', 'Uber', 'Eats', 'PURI', 'Donot', 'actually', 'eat', 'anyof', 'the', 'items', 'shown', 'Item', 'availability', 'varies', 'by', 'market', 'Other', 'restrictions', 'may', 'apply', 'See', 'app', 'for', 'details', 'Dan', 'ad', 'Ot', 'Dos', 'FOOD', 'ARKLAN']
# Von spaCy erkannte Entitäten: {'eats alurminum foit om foil', 'ot dos food arklan', 'la', 'hopey toasted', 'donoteat', 'nyc', 'dan', 'eats and dont eats uber eats puri', 'item'}
# Bereinigter Text ohne Sonderzeichen: 5G Home Internet router depieted verizon 12tia007 Introducing SG Internet for Home  Business 5G Home and 5G Business Internet available in select areas
# Aufgeteilte Wörter (Kleinschreibung): ['5G', 'Home', 'Internet', 'router', 'depieted', 'verizon', '12tia007', 'Introducing', 'SG', 'Internet', 'for', 'Home', 'Business', '5G', 'Home', 'and', '5G', 'Business', 'Internet', 'available', 'in', 'select', 'areas']
# Von spaCy erkannte Entitäten: {'5', 'g home', 'g home internet', 'introducing sg internet for home  business 5'}
# Bereinigter Text ohne Sonderzeichen: 3i Go Le ta STop talae Wae Weun STop Wte 4u GoALO 13i STOP 4ii 7T Tatl Wg Wue We 7OI Vi STOp STOp e duaehue Forala uaade ISTop For  Stop STOp 46h NoJ 40t ISice Iur  Guililueg Aelale Fuiltlins vroom vroom finance all online
# Aufgeteilte Wörter (Kleinschreibung): ['3i', 'Go', 'Le', 'ta', 'STop', 'talae', 'Wae', 'Weun', 'STop', 'Wte', '4u', 'GoALO', '13i', 'STOP', '4ii', '7T', 'Tatl', 'Wg', 'Wue', 'We', '7OI', 'Vi', 'STOp', 'STOp', 'e', 'duaehue', 'Forala', 'uaade', 'ISTop', 'For', 'Stop', 'STOp', '46h', 'NoJ', '40t', 'ISice', 'Iur', 'Guililueg', 'Aelale', 'Fuiltlins', 'vroom', 'vroom', 'finance', 'all', 'online']
# Von spaCy erkannte Entitäten: {'istop', '3i', 'wte', 'isice iur', 'guililueg aelale fuiltlins', 'forala', 'vi', '40', '13i', 'wae weun', 'tatl wg wue'}
# Bereinigter Text ohne Sonderzeichen: 09470420i7 4984d 202012 Seth T was struck by lightning May  09470420i7 4984d neU_U 0941041044 J9aid Embrace electricity PLUS wallbox
# Aufgeteilte Wörter (Kleinschreibung): ['09470420i7', '4984d', '202012', 'Seth', 'T', 'was', 'struck', 'by', 'lightning', 'May', '09470420i7', '4984d', 'neU_U', '0941041044', 'J9aid', 'Embrace', 'electricity', 'PLUS', 'wallbox']
# Von spaCy erkannte Entitäten: {'may  09470420i7 4984d neu_u 0941041044', '4984d 202012', 'seth t', 'j9aid embrace'}
# Bereinigter Text ohne Sonderzeichen: els WeatherTech WeatherTech WeatherTech n Weai Wea om WeatherTeche_com
# Aufgeteilte Wörter (Kleinschreibung): ['els', 'WeatherTech', 'WeatherTech', 'WeatherTech', 'n', 'Weai', 'Wea', 'om', 'WeatherTeche_com']
# Von spaCy erkannte Entitäten: {'weathertech'}
# Ergebnisse wurden erfolgreich in 'ocr_to_merge.csv' gespeichert.

# %%
texts = [
    "Owner' of the car",
    "Owner's rights",
    "This is a test, and we'll see if it's working.",
    "Special chars like #, $, and % should be gone!",
    "Don't forget John's car isn't here."
]

# Anwendung auf die Beispieltexte
for text in texts:
    result = clean_recognized_text_with_spacy(text)
    print(f"Original: {text}")
    print(f"Gereinigt: {result}")
    print()
# Out:
# Bereinigter Text ohne Sonderzeichen: Owner of the car
# Aufgeteilte Wörter (Kleinschreibung): ['Owner', 'of', 'the', 'car']
# Von spaCy erkannte Entitäten: set()
# Original: Owner' of the car
# Gereinigt: Owner of the car
#
# Bereinigter Text ohne Sonderzeichen: Owner's rights
# Aufgeteilte Wörter (Kleinschreibung): ["Owner's", 'rights']
# Von spaCy erkannte Entitäten: {'owner'}
# Original: Owner's rights
# Gereinigt: Owner's rights
#
# Bereinigter Text ohne Sonderzeichen: This is a test and we'll see if it's working
# Aufgeteilte Wörter (Kleinschreibung): ['This', 'is', 'a', 'test', 'and', "we'll", 'see', 'if', "it's", 'working']
# Von spaCy erkannte Entitäten: set()
# Original: This is a test, and we'll see if it's working.
# Gereinigt: This is a test and we'll see if it's working
#
# Bereinigter Text ohne Sonderzeichen: Special chars like   and  should be gone
# Aufgeteilte Wörter (Kleinschreibung): ['Special', 'chars', 'like', 'and', 'should', 'be', 'gone']
# Von spaCy erkannte Entitäten: set()
# Original: Special chars like #, $, and % should be gone!
# Gereinigt: Special chars like and should be gone
#
# Bereinigter Text ohne Sonderzeichen: Don't forget John's car isn't here
# Aufgeteilte Wörter (Kleinschreibung): ["Don't", 'forget', "John's", 'car', "isn't", 'here']
# Von spaCy erkannte Entitäten: {'john'}
# Original: Don't forget John's car isn't here.
# Gereinigt: Don't forget John's car isn't here
