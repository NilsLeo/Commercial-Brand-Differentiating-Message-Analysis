# %%
from dotenv import load_dotenv
import os
import pandas as pd
import cv2
from easyocr import Reader

# %%
# Initialisiere EasyOCR mit der gewünschten Sprache (in dem Fall Englisch)
reader = Reader(['en'], gpu=True)

# %% [markdown]
# # Create output list for individual adverts

# %%
# Definiere den Pfad zu deinem Zielordner
target_folder = "/home/giulia/Commercial-Brand-Differentiating-Message-Analysis/01_input_frames_all/2016/ADs_IG_2016/AD0417"

# %% [markdown]
# ### Methode 2: Wasserzeichen abdecken mit schwarzen Box

# %%
# Funktion: Wasserzeichen-Bereich abdecken
def cover_watermark(frame, x, y, w, h, method="black"):
    """
    Überdeckt den Wasserzeichen-Bereich in einem Bild.
    Args:
    - frame: Das Bild/Frame (numpy-Array)
    - x, y: Obere linke Ecke des Wasserzeichen-Bereichs
    - w, h: Breite und Höhe des Wasserzeichen-Bereichs
    - method: Methode zum Abdecken ("black" oder "blur")
    """
    roi = frame[y:y+h, x:x+w]
    if method == "black":
        # Füllt den Bereich mit Schwarz
        frame[y:y+h, x:x+w] = (0, 0, 0)
    elif method == "blur":
        # Wendet einen Weichzeichner auf den Bereich an
        frame[y:y+h, x:x+w] = cv2.GaussianBlur(roi, (15, 15), 0)
    return frame

# %% [markdown]
# neue procee

# %%
def process_frames_with_watermark_removal(frames, x, y, w, h, method="black"):
    """
    Entfernt Wasserzeichen und führt OCR auf allen Frames durch, gruppiert die Ergebnisse nach Frames.
    Args:
        frames (List[Dict]): Eine Liste von Dictionaries mit Frame-Pfad und Werbungsnamen.
        x, y (int): Obere linke Ecke des Wasserzeichen-Bereichs.
        w, h (int): Breite und Höhe des Wasserzeichen-Bereichs.
        method (str): Methode zum Abdecken des Wasserzeichens ("black" oder "blur").

    Returns:
        pd.DataFrame: Ein DataFrame mit den gruppierten OCR-Ergebnissen (Spalten: Frame, Recognized_Text).
    """
    results_list = []

    # Iteriere durch alle Frames
    for frame_info in frames:
        ad_name = frame_info["ad"]
        frame_path = frame_info["frame_path"]

        # Lade das Bild
        image = cv2.imread(frame_path)

        # Abdeckung des Wasserzeichens
        image = cover_watermark(image, x, y, w, h, method)

        # Perform text recognition with EasyOCR (nur auf das abgedeckte Bild)
        ocr_results = reader.readtext(image)

        # Ergebnisse speichern
        for (bbox, text, prob) in ocr_results:
            # Überprüfe, ob der Text gültig ist (nicht leer oder nur Sonderzeichen)
            if text and text.strip() and len(text.strip()) > 1:  # Sicherstellen, dass der Text sinnvoll ist
                results_list.append({
                    "Frame": os.path.basename(frame_path),  # Nur der Dateiname
                    "Recognized_Text": text.strip(),       # Direkter Text ohne zusätzliche Filterung
                })

    # Ergebnisse in DataFrame umwandeln
    results_df = pd.DataFrame(results_list)

    # Gruppiere die Ergebnisse nach Frames
    merged_results = (
        results_df.groupby("Frame")
        .agg({
            "Recognized_Text": lambda x: ", ".join(x),  # Kombiniere alle erkannten Texte pro Frame
        })
        .reset_index()
    )

    return merged_results

# %% [markdown]
# ### Duplikate entfernen

# %%
from collections import Counter
from rapidfuzz import fuzz

# Funktion: Gruppiere Texte nach Ähnlichkeit und wähle den häufigsten
def remove_similar_texts(texts, threshold=80):
    text_groups = []
    for text in texts:
        group_found = False
        for group in text_groups:
            if fuzz.ratio(text, group[0]) >= threshold:  # Überprüfe Ähnlichkeit
                group.append(text)
                group_found = True
                break
        if not group_found:
            text_groups.append([text])
    # Wähle pro Gruppe den häufigsten Text
    return [Counter(group).most_common(1)[0][0] for group in text_groups]


# Funktion: Erstelle die bereinigte Tabelle
def create_cleaned_dataframe(merged_results, ad_column="Frame", text_column="Recognized_Text", threshold=60):
    # Extrahiere den "Ad"-Namen aus den Frame-Namen
    merged_results["ad"] = merged_results[ad_column].apply(lambda x: x.split("_")[0])  
    # Gruppiere nach "ad" und bereinige Texte
    cleaned_data = []
    for ad, group in merged_results.groupby("ad"):
        unique_texts = remove_similar_texts(group[text_column].tolist(), threshold=threshold)
        unique_texts = [text for text in unique_texts if text.strip()]
        combined_text = "; ".join(unique_texts)  # Kombiniere die bereinigten Texte
        cleaned_data.append({"ad": ad, "recognized_text": combined_text})
    
    # Erstelle eine neue DataFrame
    cleaned_df = pd.DataFrame(cleaned_data)
    return cleaned_df

# %%
#cleaned_df.to_csv("cleaned_df_box.csv", index=False)

# %% [markdown]
# # Main Script

# %%
def load_all_frames(input_folder):
    """
    Listet alle Frames aus allen Unterordnern auf.
    Args:
        input_folder (str): Der Pfad zum Hauptordner mit den Frames.
    Returns:
        List[Dict]: Eine Liste von Dictionaries mit Frame-Pfad und zugehörigem Werbungsnamen.
    """
    frames = []
    for root, dirs, files in os.walk(input_folder):
        for file in files:
            if file.endswith((".png", ".jpg")):  # Akzeptiere nur Bilddateien
                ad_name = os.path.basename(root)  # Name des Werbungs-Ordners
                frame_path = os.path.join(root, file)
                frames.append({"ad": ad_name, "frame_path": frame_path})
    return frames

# %%
def process_all_ads(input_folder, x, y, w, h, method="black", threshold=70):
    """
    Hauptpipeline, die alle Schritte für die Verarbeitung aller Werbungen durchführt.
    Args:
        input_folder (str): Der Pfad zum Hauptordner mit den Frames.
    Returns:
        pd.DataFrame: Ein bereinigtes DataFrame mit allen Werbungen und kombinierten Texten.
    """
    # Lade alle Frames
    frames = load_all_frames(input_folder)
    
    # Führe OCR auf allen Frames durch
    ocr_results_df = process_frames_with_watermark_removal(frames, x, y, w, h, method)
    
    # Bereinige und kombiniere die Texte
    cleaned_df = create_cleaned_dataframe(ocr_results_df, threshold=threshold)
    
    return cleaned_df

# %%
input_folder = os.getenv("INPUT_FRAMES_ALL")  # Oder setze den Pfad direkt: "path/to/frames"

# %%
# Hauptskript
x, y, w, h = 62, 545, 235, 60  # Anpassen, falls nötig
method = "black"
threshold = 60

# 1. Lade alle Frames
frames = load_all_frames(input_folder)

print(f"Anzahl der geladenen Frames: {len(frames)}")
print(f"Anzahl der unterschiedlichen Werbungen: {len(set([frame['ad'] for frame in frames]))}")

# 2. Entferne Wasserzeichen und führe OCR aus
ocr_results_df = process_frames_with_watermark_removal(frames, x, y, w, h, method)
# Out:
# Anzahl der geladenen Frames: 64981
# Anzahl der unterschiedlichen Werbungen: 537

# %%
ocr_results_df
# Out:
#                        Frame                 Recognized_Text      ad
# 0      AD0252_Frame_1610.png                        Bravery:  AD0252
# 1      AD0252_Frame_1620.png                        Bravery:  AD0252
# 2      AD0252_Frame_1630.png                        Bravery:  AD0252
# 3      AD0252_Frame_1640.png  Bravery: It'5 what defines us.  AD0252
# 4      AD0252_Frame_1650.png  Bravery: It's what defines us.  AD0252
# ...                      ...                             ...     ...
# 23657   AD0801_Frame_610.png                              FN  AD0801
# 23658   AD0801_Frame_810.png                        Wea, ;om  AD0801
# 23659   AD0801_Frame_820.png                WeatherTeche_com  AD0801
# 23660   AD0801_Frame_830.png                WeatherTeche_com  AD0801
# 23661   AD0801_Frame_840.png                WeatherTeche_com  AD0801
#
# [23662 rows x 3 columns]

# %%
# 3. Bereinige die Ergebnisse und kombiniere Texte
final_results_df = create_cleaned_dataframe(ocr_results_df, text_column="Recognized_Text", threshold=60)

# 4. Zeige die Ergebnisse
from IPython.display import display
display(final_results_df)
# Out:
#          ad                                    recognized_text
# 0    AD0252  Bravery:; Bravery: It'5 what defines us.; Audi...
# 1    AD0253  AFF, MEEP; Ficlionalizalion; Acllowallzallou; ...
# 2    AD0254  soluor CNRAL, Sprint, #Mobile:, atet; MCINTRAL...
# 3    AD0255  Screen images suulal; 112z8; Fuzt;; 1e04213; s...
# 4    AD0256  BECKS, SAPPHII; bEck:, ALC /Vol, BECKS, SAPPHI...
# ..      ...                                                ...
# 530  AD0797  Uber, Eats; Foil, Aluminum; Prop food Do not e...
# 531  AD0798  verizon, 12tia007; Signupat verizon com/SG, 5G...
# 532  AD0799  3i, Go, Le ta, (STop, talae, Wae, Weun; (STop,...
# 533  AD0800  20,2012. Seth T. was struck by lightning:, May...
# 534  AD0801  els; WeatherTech', WeatherTech, WeatherTech'; ...
#
# [535 rows x 2 columns]
# Ergebnisse wurden erfolgreich in 'final_ocr_results.csv' gespeichert.

# %% [markdown]
# #### Wörter löschen, die nicht im Wörterbuch stehen

# %%
import re
import enchant

# Wörterbuch für Englisch
english_dict = enchant.Dict("en_US")

def clean_recognized_text_with_enchant(text):
    """
    Bereinigt erkannte Texte, indem bedeutungslose Symbole, Zeichen und zufällige Wörter entfernt werden.
    Prüft zusätzlich, ob Wörter im Wörterbuch vorhanden sind.
    
    Args:
        text (str): Der erkannte Text.
    Returns:
        str: Der bereinigte Text.
    """
    # Whitelist von häufigen kurzen Wörtern
    whitelist = {"in", "on", "by", "at", "to", "is", "as", "it", "of", "be", "or", "we", "an", "up", "no", "do", "am", "go", "my", "me", "us", "so"}

    # Entferne nicht-alphanumerische Zeichen, außer Leerzeichen und Kommas
    text = re.sub(r"[^\w\s]", "", text)
    print("without_sonderzeichen:", text)

    # Teile den Text in Wörter
    words_in_text = text.split()
    print("split:",words_in_text)
    # Filtere Wörter, die entweder:
    # 1. Im Wörterbuch vorkommen oder
    # 2. In der Whitelist enthalten sind
    meaningful_words = [
        word for word in words_in_text
        if english_dict.check(word) or word.lower() in whitelist
    ]

    # Kombiniere die bereinigten Wörter zurück in einen Text
    cleaned_text = " ".join(meaningful_words)

    return cleaned_text

# %%
ocr_to_merge = pd.read_csv("final_ocr_results.csv")

# %%
ocr_to_merge["cleaned_text"] = ocr_to_merge["recognized_text"].apply(clean_recognized_text_with_enchant)

#Speichere die Ergebnisse
ocr_to_merge.to_csv("ocr_to_merge.csv", index=False)
print("Ergebnisse wurden erfolgreich in 'ocr_to_merge.csv' gespeichert.")
# Out:
# without_sonderzeichen: Bravery Bravery It5 what defines us Audi CW Truth in Engineering BraveryWins SCORING SUMMARY BALTIMORE PLAYS 6 Art YARDS 51 RAVENS TIME 229 Jin 13YARD TD RECEPTION Away Fiel 22 SCORING SUMMARY BALTIMORE ANQUAN BOLDIN AtH REC TD THIS POSTSEASON MFD Art 4 REC TD IN REG SEASON RAVENS 903 Closed Course obey speed ard traffic laws Aluys PRINCIPAL ONLY PRINCE PathctpaE BHrSoN ISQHIOOL Hu bxdron ISOHOOL Hul
# split: ['Bravery', 'Bravery', 'It5', 'what', 'defines', 'us', 'Audi', 'CW', 'Truth', 'in', 'Engineering', 'BraveryWins', 'SCORING', 'SUMMARY', 'BALTIMORE', 'PLAYS', '6', 'Art', 'YARDS', '51', 'RAVENS', 'TIME', '229', 'Jin', '13YARD', 'TD', 'RECEPTION', 'Away', 'Fiel', '22', 'SCORING', 'SUMMARY', 'BALTIMORE', 'ANQUAN', 'BOLDIN', 'AtH', 'REC', 'TD', 'THIS', 'POSTSEASON', 'MFD', 'Art', '4', 'REC', 'TD', 'IN', 'REG', 'SEASON', 'RAVENS', '903', 'Closed', 'Course', 'obey', 'speed', 'ard', 'traffic', 'laws', 'Aluys', 'PRINCIPAL', 'ONLY', 'PRINCE', 'PathctpaE', 'BHrSoN', 'ISQHIOOL', 'Hu', 'bxdron', 'ISOHOOL', 'Hul']
# without_sonderzeichen: AFF MEEP Ficlionalizalion Acllowallzallou MeFP OF FuMula sWnon ad nothinG BEA 5 An ASTRONAUT Noput Feesan Vokd where protbmed AXE Aealo Big Gare Swerpstak sponsofed by Conn Mc da Unllcwt Varsciue MUs  X Lt Beyiris 1913206QUUPT  ends 27318 5959pmn PT For Ulerltules visit axeapollo com mollo NEW AxE APOLLO ENTER BEFORE MIDNIGHT AT AXEAPOLLO COM No purchasc ncossary Voidd wtiere prohibierl AXE Apallo Big Gamc Swccpslakes is sponsorexl by Conopco Inc  bla Unilcict Operito legaltesiderts pllI SOUs  0C IBoi dka Brgus 1913a0owpt ends 2313a1 15959pmII PT For allicial rules visit axcapollo com
# split: ['AFF', 'MEEP', 'Ficlionalizalion', 'Acllowallzallou', 'MeFP', 'OF', 'FuMula', 'sWnon', 'ad', 'nothinG', 'BEA', '5', 'An', 'ASTRONAUT', 'Noput', 'Feesan', 'Vokd', 'where', 'protbmed', 'AXE', 'Aealo', 'Big', 'Gare', 'Swerpstak', 'sponsofed', 'by', 'Conn', 'Mc', 'da', 'Unllcwt', 'Varsciue', 'MUs', 'X', 'Lt', 'Beyiris', '1913206QUUPT', 'ends', '27318', '5959pmn', 'PT', 'For', 'Ulerltules', 'visit', 'axeapollo', 'com', 'mollo', 'NEW', 'AxE', 'APOLLO', 'ENTER', 'BEFORE', 'MIDNIGHT', 'AT', 'AXEAPOLLO', 'COM', 'No', 'purchasc', 'ncossary', 'Voidd', 'wtiere', 'prohibierl', 'AXE', 'Apallo', 'Big', 'Gamc', 'Swccpslakes', 'is', 'sponsorexl', 'by', 'Conopco', 'Inc', 'bla', 'Unilcict', 'Operito', 'legaltesiderts', 'pllI', 'SOUs', '0C', 'IBoi', 'dka', 'Brgus', '1913a0owpt', 'ends', '2313a1', '15959pmII', 'PT', 'For', 'allicial', 'rules', 'visit', 'axcapollo', 'com']
# without_sonderzeichen: soluor CNRAL Sprint Mobile atet MCINTRAL T  Mobile verizon JRE MAGIC RY MO ENT veriz 88p Ko Kuv Wrot JTe Je Aneeaa churcirotc 4EADPHONES HEADPH OW PRICE FREE DELIVERY RANTEE ON ALL MAJOP APPLIANCFC Eorn Ione Kae sobi 4a Novaa MOVIES  MUSIC HOME APPLIANCES PTURF EmaGiG TOP RATED SLR CAMERAS MA WWeeen  LAPTOPS Manoir LOr 8E538uY  HExSLUssVED FxSWERYIL Screen Images Simulated Ox LAPTOPS 30 Li0n LMTOFS LAPTOPS BEST BUY EXC BEST BUY CREATIVITY UR SLEEK AN Screen Images Simuated TEST TABLETS GHT HERE MH Hels and eReader under one fool AR BESTI BUY JBVSoufons hc A Rghs Respneu BESTBU He BESTE bebydzsigo Besbuyoomae ha_etr_s OFBBV Souots hc BUYgo T SOLUTION CENTRAL Any E CAraER AnypHGTE Sprint All MoNe puce 27
# split: ['soluor', 'CNRAL', 'Sprint', 'Mobile', 'atet', 'MCINTRAL', 'T', 'Mobile', 'verizon', 'JRE', 'MAGIC', 'RY', 'MO', 'ENT', 'veriz', '88p', 'Ko', 'Kuv', 'Wrot', 'JTe', 'Je', 'Aneeaa', 'churcirotc', '4EADPHONES', 'HEADPH', 'OW', 'PRICE', 'FREE', 'DELIVERY', 'RANTEE', 'ON', 'ALL', 'MAJOP', 'APPLIANCFC', 'Eorn', 'Ione', 'Kae', 'sobi', '4a', 'Novaa', 'MOVIES', 'MUSIC', 'HOME', 'APPLIANCES', 'PTURF', 'EmaGiG', 'TOP', 'RATED', 'SLR', 'CAMERAS', 'MA', 'WWeeen', 'LAPTOPS', 'Manoir', 'LOr', '8E538uY', 'HExSLUssVED', 'FxSWERYIL', 'Screen', 'Images', 'Simulated', 'Ox', 'LAPTOPS', '30', 'Li0n', 'LMTOFS', 'LAPTOPS', 'BEST', 'BUY', 'EXC', 'BEST', 'BUY', 'CREATIVITY', 'UR', 'SLEEK', 'AN', 'Screen', 'Images', 'Simuated', 'TEST', 'TABLETS', 'GHT', 'HERE', 'MH', 'Hels', 'and', 'eReader', 'under', 'one', 'fool', 'AR', 'BESTI', 'BUY', 'JBVSoufons', 'hc', 'A', 'Rghs', 'Respneu', 'BESTBU', 'He', 'BESTE', 'bebydzsigo', 'Besbuyoomae', 'ha_etr_s', 'OFBBV', 'Souots', 'hc', 'BUYgo', 'T', 'SOLUTION', 'CENTRAL', 'Any', 'E', 'CAraER', 'AnypHGTE', 'Sprint', 'All', 'MoNe', 'puce', '27']
# without_sonderzeichen: Screen images suulal 112z8 Fuzt 1e04213 si Coming soon lo select US carriers STOPI Iff BlackBerry See what it can do at blackberry comzlo BlackBery Blnck Rorry Hub annie Malthowe Mcllss Davcy Hisham Athas Revlw02 Sales Mch Mutu Mtr BlackBerry Steptuan Dutke Trevor Camcron See what it can do at blackberry comzlo Annle Mattnowt BlackBery Ver Miayes Slanu
# split: ['Screen', 'images', 'suulal', '112z8', 'Fuzt', '1e04213', 'si', 'Coming', 'soon', 'lo', 'select', 'US', 'carriers', 'STOPI', 'Iff', 'BlackBerry', 'See', 'what', 'it', 'can', 'do', 'at', 'blackberry', 'comzlo', 'BlackBery', 'Blnck', 'Rorry', 'Hub', 'annie', 'Malthowe', 'Mcllss', 'Davcy', 'Hisham', 'Athas', 'Revlw02', 'Sales', 'Mch', 'Mutu', 'Mtr', 'BlackBerry', 'Steptuan', 'Dutke', 'Trevor', 'Camcron', 'See', 'what', 'it', 'can', 'do', 'at', 'blackberry', 'comzlo', 'Annle', 'Mattnowt', 'BlackBery', 'Ver', 'Miayes', 'Slanu']
# without_sonderzeichen: BECKS SAPPHII bEck ALC Vol BECKS SAPPHIRE eqmansapphire Mors ShaothTaSTe BECKS ALcno DECKS SAPPHIRE TADGTE BECKS SAPPHIRE RMAN SAPPHIRE SMOOTH TASTE HOPS RE PS Ua Mta IE PE BECKS ApDUide REG BEc 6 RTG BEd 36 BEq 7696  SAR nccKS SAPPHIRE Haonann BECKS TALc Ivol becK  APPHird Panftia BECKS ALCJvOl MAPPHipe necis bECKS TEci ALc Jvol PphiR Pbhi 6Ecro Cvoi Lc DECI5 bECKS IEST Ohival 73 JR bECKS THEST Galcvol cI FT OUR BECK MOOTHEST AC Vol BECKS YFT Kecis SAPPHIRE OUR BECK SMOOTHEST CVol BECKS YET KEcKS SAPPHIRE Always Euilby Responsibly OzutJ Urauarei Beck  Co  Beck Sqbuppi Deet SL Louls MO
# split: ['BECKS', 'SAPPHII', 'bEck', 'ALC', 'Vol', 'BECKS', 'SAPPHIRE', 'eqmansapphire', 'Mors', 'ShaothTaSTe', 'BECKS', 'ALcno', 'DECKS', 'SAPPHIRE', 'TADGTE', 'BECKS', 'SAPPHIRE', 'RMAN', 'SAPPHIRE', 'SMOOTH', 'TASTE', 'HOPS', 'RE', 'PS', 'Ua', 'Mta', 'IE', 'PE', 'BECKS', 'ApDUide', 'REG', 'BEc', '6', 'RTG', 'BEd', '36', 'BEq', '7696', 'SAR', 'nccKS', 'SAPPHIRE', 'Haonann', 'BECKS', 'TALc', 'Ivol', 'becK', 'APPHird', 'Panftia', 'BECKS', 'ALCJvOl', 'MAPPHipe', 'necis', 'bECKS', 'TEci', 'ALc', 'Jvol', 'PphiR', 'Pbhi', '6Ecro', 'Cvoi', 'Lc', 'DECI5', 'bECKS', 'IEST', 'Ohival', '73', 'JR', 'bECKS', 'THEST', 'Galcvol', 'cI', 'FT', 'OUR', 'BECK', 'MOOTHEST', 'AC', 'Vol', 'BECKS', 'YFT', 'Kecis', 'SAPPHIRE', 'OUR', 'BECK', 'SMOOTHEST', 'CVol', 'BECKS', 'YET', 'KEcKS', 'SAPPHIRE', 'Always', 'Euilby', 'Responsibly', 'OzutJ', 'Urauarei', 'Beck', 'Co', 'Beck', 'Sqbuppi', 'Deet', 'SL', 'Louls', 'MO']
# without_sonderzeichen: euttedser BLACK CAOWI U AoLoEleeetn Ss ENjOY Rei ONSIBLY 02013AB BuDwEiscR Buck Gnowx Laoen St Louis MO 18 IcK CROVM LoTALCND NEW FBudieioet BLACK CROWN BLACK CROWN
# split: ['euttedser', 'BLACK', 'CAOWI', 'U', 'AoLoEleeetn', 'Ss', 'ENjOY', 'Rei', 'ONSIBLY', '02013AB', 'BuDwEiscR', 'Buck', 'Gnowx', 'Laoen', 'St', 'Louis', 'MO', '18', 'IcK', 'CROVM', 'LoTALCND', 'NEW', 'FBudieioet', 'BLACK', 'CROWN', 'BLACK', 'CROWN']
# without_sonderzeichen: 1V croln WAck CMowh McTcm ucK cicad QucK Cnotyh Mccnuat Enjoy ReapOnSIBLY 02013 A B BuawEIsEn Buck CnowN LAGEn ST Lours MO NJoy RESRONSIBL iaB BUSNELRW Blaci S7 Louie MQ ha AGER ENJOy Reeronsibly 02013 A Blowciser Blck Craxn LAceR St Loure MG TucK CAOM Lot NEW FBudieioed BLACK CROWN BLACK CROWN
# split: ['1V', 'croln', 'WAck', 'CMowh', 'McTcm', 'ucK', 'cicad', 'QucK', 'Cnotyh', 'Mccnuat', 'Enjoy', 'ReapOnSIBLY', '02013', 'A', 'B', 'BuawEIsEn', 'Buck', 'CnowN', 'LAGEn', 'ST', 'Lours', 'MO', 'NJoy', 'RESRONSIBL', 'iaB', 'BUSNELRW', 'Blaci', 'S7', 'Louie', 'MQ', 'ha', 'AGER', 'ENJOy', 'Reeronsibly', '02013', 'A', 'Blowciser', 'Blck', 'Craxn', 'LAceR', 'St', 'Loure', 'MG', 'TucK', 'CAOM', 'Lot', 'NEW', 'FBudieioed', 'BLACK', 'CROWN', 'BLACK', 'CROWN']
# without_sonderzeichen: Gd TRANC 1 ta ITS ONLY WEIRD IF IT DOESNT WORK BuE HE BLD gha TKD FLVI EDToL Staae EMJOY RESPONSIBLY 2013 ANHCUSER DUSCH DUD LIGHT DCER ST LOUIS MO Ocom Ane edn Jn D0o 238 BuD UNT Shon Aqess Bar 8243 IStadIuM 15 BuD VSM 731 450D USH B3L B0D Ligh Ustadiun 8248 ELD 88 LISNT EuD Da Ga
# split: ['Gd', 'TRANC', '1', 'ta', 'ITS', 'ONLY', 'WEIRD', 'IF', 'IT', 'DOESNT', 'WORK', 'BuE', 'HE', 'BLD', 'gha', 'TKD', 'FLVI', 'EDToL', 'Staae', 'EMJOY', 'RESPONSIBLY', '2013', 'ANHCUSER', 'DUSCH', 'DUD', 'LIGHT', 'DCER', 'ST', 'LOUIS', 'MO', 'Ocom', 'Ane', 'edn', 'Jn', 'D0o', '238', 'BuD', 'UNT', 'Shon', 'Aqess', 'Bar', '8243', 'IStadIuM', '15', 'BuD', 'VSM', '731', '450D', 'USH', 'B3L', 'B0D', 'Ligh', 'Ustadiun', '8248', 'ELD', '88', 'LISNT', 'EuD', 'Da', 'Ga']
# without_sonderzeichen: ol 7605 6as G05 JV Kc Ka UBudoveisehe CLYDESDALES ENjoy RESPONSIBLY 02013 ANHEUSERBuScH BuDwEISER BEER St Louis MO ABudtcisor curbe SBudwciser CLDLUDal JNAL OBudeisen CLY DESDALEB THREE YEARS LATER HeVou Coming to Things ppening Clydesdales Budweiser Chicago
# split: ['ol', '7605', '6as', 'G05', 'JV', 'Kc', 'Ka', 'UBudoveisehe', 'CLYDESDALES', 'ENjoy', 'RESPONSIBLY', '02013', 'ANHEUSERBuScH', 'BuDwEISER', 'BEER', 'St', 'Louis', 'MO', 'ABudtcisor', 'curbe', 'SBudwciser', 'CLDLUDal', 'JNAL', 'OBudeisen', 'CLY', 'DESDALEB', 'THREE', 'YEARS', 'LATER', 'HeVou', 'Coming', 'to', 'Things', 'ppening', 'Clydesdales', 'Budweiser', 'Chicago']
# without_sonderzeichen: Calvin Klein Klein Calvin Klein 7cin Vin Clt i calic C 0 N  E P T Calvin Klein C 0 N  E P T calvinklein com calvinklein
# split: ['Calvin', 'Klein', 'Klein', 'Calvin', 'Klein', '7cin', 'Vin', 'Clt', 'i', 'calic', 'C', '0', 'N', 'E', 'P', 'T', 'Calvin', 'Klein', 'C', '0', 'N', 'E', 'P', 'T', 'calvinklein', 'com', 'calvinklein']
# without_sonderzeichen: carscom com cors carscom Fld carscom ALL DRIVE iodo nodrama nd
# split: ['carscom', 'com', 'cors', 'carscom', 'Fld', 'carscom', 'ALL', 'DRIVE', 'iodo', 'nodrama', 'nd']
# without_sonderzeichen: Jry 20 Healestate Realoey Cotpany GEHTURY 210 ans MARTER bolder TER are Raplstered  Bx Cemelltn Estal LLC Junumly Con Equal Mousing Upeortumily  Fack LEMTuAY Qtce I2 Indenel SMARTER BOLDER FASTER C21COM Century 21 Real Estate LLC Realoey Compan CEMTURY 210 and SHARTER BOLDER FASTER  are Replstered Trademarks Oxned By Century Real Estate LLC An Equal Opportunily Company Equal Housing Opportunely  Each CENTURY 21 ce Independently Owcned Operated Clur2l
# split: ['Jry', '20', 'Healestate', 'Realoey', 'Cotpany', 'GEHTURY', '210', 'ans', 'MARTER', 'bolder', 'TER', 'are', 'Raplstered', 'Bx', 'Cemelltn', 'Estal', 'LLC', 'Junumly', 'Con', 'Equal', 'Mousing', 'Upeortumily', 'Fack', 'LEMTuAY', 'Qtce', 'I2', 'Indenel', 'SMARTER', 'BOLDER', 'FASTER', 'C21COM', 'Century', '21', 'Real', 'Estate', 'LLC', 'Realoey', 'Compan', 'CEMTURY', '210', 'and', 'SHARTER', 'BOLDER', 'FASTER', 'are', 'Replstered', 'Trademarks', 'Oxned', 'By', 'Century', 'Real', 'Estate', 'LLC', 'An', 'Equal', 'Opportunily', 'Company', 'Equal', 'Housing', 'Opportunely', 'Each', 'CENTURY', '21', 'ce', 'Independently', 'Owcned', 'Operated', 'Clur2l']
# without_sonderzeichen: Traired Dadlander Do not alemn Trairicd Dadlal Edo Ia mowpl attompg Wadlaulele_Vo nutrattempi lcatcta MILES 50 MHLAD kcc tod 50 ES lca tcl MhHab Vote now to decide who wins COKECHASE COM ca Ccl Aca Kata Icg Cd Vicn Cc a 6cl Dula Companv Knd V9j5 Cxl h ojiWbWo1 tij6s  IoN 10966 Wb N u ciieu Eoufe Deseeue tjltetexwperele Me el U Cola 7Z64 Wpe apik Keseynylojul Bote Desion are reqistered Ea of Ine Coga Cola ompame 49 Ionidai JJ mn lcaGca PF Pf AC
# split: ['Traired', 'Dadlander', 'Do', 'not', 'alemn', 'Trairicd', 'Dadlal', 'Edo', 'Ia', 'mowpl', 'attompg', 'Wadlaulele_Vo', 'nutrattempi', 'lcatcta', 'MILES', '50', 'MHLAD', 'kcc', 'tod', '50', 'ES', 'lca', 'tcl', 'MhHab', 'Vote', 'now', 'to', 'decide', 'who', 'wins', 'COKECHASE', 'COM', 'ca', 'Ccl', 'Aca', 'Kata', 'Icg', 'Cd', 'Vicn', 'Cc', 'a', '6cl', 'Dula', 'Companv', 'Knd', 'V9j5', 'Cxl', 'h', 'ojiWbWo1', 'tij6s', 'IoN', '10966', 'Wb', 'N', 'u', 'ciieu', 'Eoufe', 'Deseeue', 'tjltetexwperele', 'Me', 'el', 'U', 'Cola', '7Z64', 'Wpe', 'apik', 'Keseynylojul', 'Bote', 'Desion', 'are', 'reqistered', 'Ea', 'of', 'Ine', 'Coga', 'Cola', 'ompame', '49', 'Ionidai', 'JJ', 'mn', 'lcaGca', 'PF', 'Pf', 'AC']
# without_sonderzeichen: SECURITY CAMERAS AROUND THE WORLD ALSO CAPTURE PEOPLE STEALING MUSIC DDICTS Zmqin SUl 24 LEPL2008 161940 Sul5  SEPL2O08 161940 HONEST CKPOCKETS S C DF1ea E9i7 AND POTAS CH EA 029  1208 2uug 090324 ATTACKS F FRIENDSHIP Ava1z4 Sbu38 4i LKT 0500 180112 UNEXPECTED REMEN AND PEACEFUL H6 LSu ARRIORS 01122011 01 00 58233 QzA 21092007 451844 LETS LOOK AT THE WORLD A LITTLE DIFFERENTLY ula Coke Open Happiness and the Contour Bottle Design are registered trademarks of the Coca Cola Company LETS LOOK AT THE WORLD A LITTLE DIFFERENTLY 6opeteXapep e licaGclopen happiness
# split: ['SECURITY', 'CAMERAS', 'AROUND', 'THE', 'WORLD', 'ALSO', 'CAPTURE', 'PEOPLE', 'STEALING', 'MUSIC', 'DDICTS', 'Zmqin', 'SUl', '24', 'LEPL2008', '161940', 'Sul5', 'SEPL2O08', '161940', 'HONEST', 'CKPOCKETS', 'S', 'C', 'DF1ea', 'E9i7', 'AND', 'POTAS', 'CH', 'EA', '029', '1208', '2uug', '090324', 'ATTACKS', 'F', 'FRIENDSHIP', 'Ava1z4', 'Sbu38', '4i', 'LKT', '0500', '180112', 'UNEXPECTED', 'REME
# split: ['Dorits', 'Cheed', 'Nacho', 'Goat', 'Sale', 'Joritos', 'pritol', 'Duiitus', 'poxite', 'Chcs', 'Ghcct', 'Doritos', 'Doritos', 'Doritos', 'Dalito', 'Da', 'dloniets', 'Dot', 'Jotito', 'Dorita', 'jorito', 'LOs', 'Docho', 'b_rto', 'LC', 'peritu', 'Chee', 'Vorn', 'TEMl', 'hee', 'Dorito', 'orit', 'Dorios', 'rito', 'Dorito', 'Iu', 'prito', 'Qoritosjorito', 'Doritos', 'Doritos', 'Doritos', 'Dorite', 'voritos', 'ator', 'Itos', 'joritos', 'Joritos', 'Jop', 'britos', 'UJorito', 'Joritos', 'Chees', 'Kecho', 'iton', 'nor', 'Mulo', '42', 'bags', 'later', '156', 'bags', 'later', 'THE', 'NEXT', 'DAY', 'Qo', 'Jotf', 'Voritos', 'pote', 'Dorito', 'Joritos', 'GOAT', 'SALF', 'Ol', 'rito', 'Iriic', 'Dinoc', 'GOAT', 'SALF', 'Don', 'Auc', 'Dorili', 'onlts', 'Wt', 'Gur', 'Do', 'o0flto', 'ch', 'Oon', 'Docit', 'e', 'Jorin', 'Jros', 'orito']
# without_sonderzeichen: edata basedon muliple independent souroes alu zyvaydevendlngon ndlvidual vesiorcicunstalces Protessional stunts Do noL attelpe etrade com You must be 18 vears ofage to open an ETRADE Securties account Securities products and services are offered by ETRADE Securities LLC Member FINRNSHPC System response and account access times willvary 02013 ETRADE Financial Corporation
# split: ['edata', 'basedon', 'muliple', 'independent', 'souroes', 'alu', 'zyvaydevendlngon', 'ndlvidual', 'vesiorcicunstalces', 'Protessional', 'stunts', 'Do', 'noL', 'attelpe', 'etrade', 'com', 'You', 'must', 'be', '18', 'vears', 'ofage', 'to', 'open', 'an', 'ETRADE', 'Securties', 'account', 'Securities', 'products', 'and', 'services', 'are', 'offered', 'by', 'ETRADE', 'Securities', 'LLC', 'Member', 'FINRNSHPC', 'System', 'response', 'and', 'account', 'access', 'times', 'willvary', '02013', 'ETRADE', 'Financial', 'Corporation']
# without_sonderzeichen: Rd Mt eeref Sid Janot S4 Japt Jeot Degt ITS ABOUT TIME YOU HAD FAVORITE TSHIRT GILDAN EVERY THREAD COUNTS
# split: ['Rd', 'Mt', 'eeref', 'Sid', 'Janot', 'S4', 'Japt', 'Jeot', 'Degt', 'ITS', 'ABOUT', 'TIME', 'YOU', 'HAD', 'FAVORITE', 'TSHIRT', 'GILDAN', 'EVERY', 'THREAD', 'COUNTS']
# without_sonderzeichen: Iddyc Ss Ga Daddy COM Iddy Jkiss WHEN SEXY MEETS SMART YOUR SMALL BUSINESS SCORES kiss GET YOUR DOMAIN AND WEBSITE SSS Go Daddycov SEE MORE NOW AT GODADDYCOM
# split: ['Iddyc', 'Ss', 'Ga', 'Daddy', 'COM', 'Iddy', 'Jkiss', 'WHEN', 'SEXY', 'MEETS', 'SMART', 'YOUR', 'SMALL', 'BUSINESS', 'SCORES', 'kiss', 'GET', 'YOUR', 'DOMAIN', 'AND', 'WEBSITE', 'SSS', 'Go', 'Daddycov', 'SEE', 'MORE', 'NOW', 'AT', 'GODADDYCOM']
# without_sonderzeichen: TM trademarks Mars Incorporated 2013 Mi 0o Uo rated 2013 6 Ac Fresh Il chocolates better with betterwithmms
# split: ['TM', 'trademarks', 'Mars', 'Incorporated', '2013', 'Mi', '0o', 'Uo', 'rated', '2013', '6', 'Ac', 'Fresh', 'Il', 'chocolates', 'better', 'with', 'betterwithmms']
# without_sonderzeichen: Mio FIT Mio FIT Mio FIT NEW Mio FIT WITH ELECTROLYTES Always dilute ChangeStuff Mio FIT liqud UMac ElEctrOLYTES 8B VITAMINS Hera 18 BLaST ChangeStuff NEW Miq FIT Mil Fit qund WaTEA NTRQNTS EnhAncft ChangeStuff
# split: ['Mio', 'FIT', 'Mio', 'FIT', 'Mio', 'FIT', 'NEW', 'Mio', 'FIT', 'WITH', 'ELECTROLYTES', 'Always', 'dilute', 'ChangeStuff', 'Mio', 'FIT', 'liqud', 'UMac', 'ElEctrOLYTES', '8B', 'VITAMINS', 'Hera', '18', 'BLaST', 'ChangeStuff', 'NEW', 'Miq', 'FIT', 'Mil', 'Fit', 'qund', 'WaTEA', 'NTRQNTS', 'EnhAncft', 'ChangeStuff']
# without_sonderzeichen: NETwonK Jagvars 3n DEGd SAN Ynlk Uibe INv AN MN Qu DRAFT DRAFT Gnr 818 Ch Chl 848 an WD SANDCUSTLE 201 Netwa S1MDCISTLE MD RA 2013 Su TOTTIN WFV SC 0UTIN G COMBINE 2013 2013 nfl comlprimetime WD SMIE BA NFL nfl comlprimetime ND BA nd SLLCISTLE LETWioic WF nfl comlprimetime BA ICT IVETwOnIt CIFL Netwonit PLATER REGISTAATOH WFV PLATER Ecoistration NFL NfD couTido PATH T0 PRINETINE COMBINE 21loe 2013 40 ARD Uot ArNOun DASA WFV 2019 VerticAL JUMp JGOOD COMBIN JDEL 2013 013 INDIA NAPOLIS 12 NFLcOM 21l65 21o8 2f5 2ib5 JA Ca Cok Naraonit CHIEFS dh Foh We Netwontt CHIERS h nd
# split: ['NETwonK', 'Jagvars', '3n', 'DEGd', 'SAN', 'Ynlk', 'Uibe', 'INv', 'AN', 'MN', 'Qu', 'DRAFT', 'DRAFT', 'Gnr', '818', 'Ch', 'Chl', '848', 'an', 'WD', 'SANDCUSTLE', '201', 'Netwa', 'S1MDCISTLE', 'MD', 'RA', '2013', 'Su', 'TOTTIN', 'WFV', 'SC', '0UTIN', 'G', 'COMBINE', '2013', '2013', 'nfl', 'comlprimetime', 'WD', 'SMIE', 'BA', 'NFL', 'nfl', 'comlprimetime', 'ND', 'BA', 'nd', 'SLLCISTLE', 'LETWioic', 'WF', 'nfl', 'comlprimetime', 'BA', 'ICT', 'IVETwOnIt', 'CIFL', 'Netwonit', 'PLATER', 'REGISTAATOH', 'WFV', 'PLATER', 'Ecoistration', 'NFL', 'NfD', 'couTido', 'PATH', 'T0', 'PRINETINE', 'COMBINE', '21loe', '2013', '40', 'ARD
# without_sonderzeichen: DJo not attempt Vo not allcinpl COLA ESS 14 Tastt Sugar Usie UGar next TS1 12 6p pepsi next First million it for FREE at PepsiNEXTcom 60 Iess sugar than PepsiCola  PEPSICOLA PEPSI NEXT Ihe Pepsi Globe and DRINK IT TO BELIEVE IT are registered trademarks of PepsiCo Inc try
# split: ['DJo', 'not', 'attempt', 'Vo', 'not', 'allcinpl', 'COLA', 'ESS', '14', 'Tastt', 'Sugar', 'Usie', 'UGar', 'next', 'TS1', '12', '6p', 'pepsi', 'next', 'First', 'million', 'it', 'for', 'FREE', 'at', 'PepsiNEXTcom', '60', 'Iess', 'sugar', 'than', 'PepsiCola', 'PEPSICOLA', 'PEPSI', 'NEXT', 'Ihe', 'Pepsi', 'Globe', 'and', 'DRINK', 'IT', 'TO', 'BELIEVE', 'IT', 'are', 'registered', 'trademarks', 'of', 'PepsiCo', 'Inc', 'try']
# without_sonderzeichen: Kn HU Glose Glose Smt Wuh LL 6 IS Accessory sold separately IcLO OLO Uoool Icooe Oicool X2 SamSUng SaMSUMO SAMSUNg The Next Big Thing is Here Samsung GALAXY TheNextBigThing Kje Ln 3 u Screen images simulated  Appearance of device may vary Mv
# split: ['Kn', 'HU', 'Glose', 'Glose', 'Smt', 'Wuh', 'LL', '6', 'IS', 'Accessory', 'sold', 'separately', 'IcLO', 'OLO', 'Uoool', 'Icooe', 'Oicool', 'X2', 'SamSUng', 'SaMSUMO', 'SAMSUNg', 'The', 'Next', 'Big', 'Thing', 'is', 'Here', 'Samsung', 'GALAXY', 'TheNextBigThing', 'Kje', 'Ln', '3', 'u', 'Screen', 'images', 'simulated', 'Appearance', 'of', 'device', 'may', 'vary', 'Mv']
# without_sonderzeichen: skechers Gorune DESIGNED FOR SPEED
# split: ['skechers', 'Gorune', 'DESIGNED', 'FOR', 'SPEED']
# without_sonderzeichen: 531149 634140 sodastream Source Euromonitor Packaging  Beverages Report USA 2012 sodastream sodastreamcom
# split: ['531149', '634140', 'sodastream', 'Source', 'Euromonitor', 'Packaging', 'Beverages', 'Report', 'USA', '2012', 'sodastream', 'sodastreamcom']
# without_sonderzeichen: Onzrulti Ha IL Uchon Uahunt HANDLE IT BOwer Speed Ytick 4m HL Ms Vm Oe HedOurtn HLeort Mhrd Outtt MLe Oee Uidouttn HleOe 7doutn LdOuttt pewer Fdese Deobora Speedh Ytick Dont sweat it HANDLE ITS Dower Fnesa Deodon Speed rtick TWEET YOUR HANDLEIT MOMENT DOweR Gpiesh Dosor Speed Ytick
# split: ['Onzrulti', 'Ha', 'IL', 'Uchon', 'Uahunt', 'HANDLE', 'IT', 'BOwer', 'Speed', 'Ytick', '4m', 'HL', 'Ms', 'Vm', 'Oe', 'HedOurtn', 'HLeort', 'Mhrd', 'Outtt', 'MLe', 'Oee', 'Uidouttn', 'HleOe', '7doutn', 'LdOuttt', 'pewer', 'Fdese', 'Deobora', 'Speedh', 'Ytick', 'Dont', 'sweat', 'it', 'HANDLE', 'ITS', 'Dower', 'Fnesa', 'Deodon', 'Speed', 'rtick', 'TWEET', 'YOUR', 'HANDLEIT', 'MOMENT', 'DOweR', 'Gpiesh', 'Dosor', 'Speed', 'Ytick']
# without_sonderzeichen: 49ERS 16 16 16 1628 1I 49BRS 49117 421F RANCISCO NFL 49322 FRANCISCO 4983 Sl 19uR8 FRANCISCO OTrac WITNESSED AA MMON MQ NONTINALAND WFD 49228 JOYTANAL 4L INALAN MOA MOYIAMALAML MDM 9E6 6DM HH 01 27 Uut 44M fde fde NO STAIN IS SACRED MIRACLESTAIN MIRACLESTAINCOM NFL NNid 495e Ed Jan7 Me 495n7 Wuj 495rF JOE MONTANA MIRACLE STAIN 4U 49ut Staln F Mucaci Cach Stalh  dit I3 bxa I39 Libuu B3S cudoa cund Wd CAUTIOa CauTIOH Tyu CAuTIDA MuTIDN Cumn 49 A9Er
# split: ['49ERS', '16', '16', '16', '1628', '1I', '49BRS', '49117', '421F', 'RANCISCO', 'NFL', '49322', 'FRANCISCO', '4983', 'Sl', '19uR8', 'FRANCISCO', 'OTrac', 'WITNESSED', 'AA', 'MMON', 'MQ', 'NONTINALAND', 'WFD', '49228', 'JOYTANAL', '4L', 'INALAN', 'MOA', 'MOYIAMALAML', 'MDM', '9E6', '6DM', 'HH', '01', '27', 'Uut', '44M', 'fde', 'fde', 'NO', 'STAIN', 'IS', 'SACRED', 'MIRACLESTAIN', 'MIRACLESTAINCOM', 'NFL', 'NNid', '495e', 'Ed', 'Jan7', 'Me', '495n7', 'Wuj', '495rF', 'JOE', 'MONTANA', 'MIRACLE', 'STAIN', '4U', '49ut', 'Staln', 'F', 'Mucaci', 'Cach', 'Stalh', 'dit', 'I3', 'bxa', 'I39', 'Libuu', 'B3S', 'cudoa', 'cund', 'Wd', 'CAUTIOa', 'CauTIOH', 'Tyu', 'CAuTIDA', 'MuTIDN', 'Cumn', '49', 'A9Er']
# without_sonderzeichen: Prototype wlth options Exterlor sparetire not avallable Sirius XM Radio Inc Simulated screen shown Al Aypio Siriuskm Off OSirius XM Radio Inc Simulated screen shown E G Aadio Satelle HTRACK taAn oJAaNlo Haet ETOn K Feuulia inulate Goon Lets Go TOYOTA Places WishGranted Jl 77
# split: ['Prototype', 'wlth', 'options', 'Exterlor', 'sparetire', 'not', 'avallable', 'Sirius', 'XM', 'Radio', 'Inc', 'Simulated', 'screen', 'shown', 'Al', 'Aypio', 'Siriuskm', 'Off', 'OSirius', 'XM', 'Radio', 'Inc', 'Simulated', 'screen', 'shown', 'E', 'G', 'Aadio', 'Satelle', 'HTRACK', 'taAn', 'oJAaNlo', 'Haet', 'ETOn', 'K', 'Feuulia', 'inulate', 'Goon', 'Lets', 'Go', 'TOYOTA', 'Places', 'WishGranted', 'Jl', '77']
# without_sonderzeichen: Cn Get in Ht63944 Get in Get happy AT6J8h4 Das Aulos Das Auto GetHappy LDY Good Vibes onne Fcouan QJN
# split: ['Cn', 'Get', 'in', 'Ht63944', 'Get', 'in', 'Get', 'happy', 'AT6J8h4', 'Das', 'Aulos', 'Das', 'Auto', 'GetHappy', 'LDY', 'Good', 'Vibes', 'onne', 'Fcouan', 'QJN']
# without_sonderzeichen: XM Gs  cS  Healthy Snackin CrackinStyle
# split: ['XM', 'Gs', 'cS', 'Healthy', 'Snackin', 'CrackinStyle']
# without_sonderzeichen: YOUR DREAM IS OUT THERE GO GET IT AMERICAN FAMILY TnSuRAnce WELL PROTECT IT AMERICAN FAMILY INSURANCE longlivedreams uinnoue 6uaacIe Vadsn W Sur_ Kecbuenalde o1 LlopaDLlplelo LEEEIILLLLLAloll SIILLLL SEELILLzl LEnILLLLL Lo 4 3ll5l4LLl Lulull LEEDdill L Lo 3l55LLLLL 77
# split: ['YOUR', 'DREAM', 'IS', 'OUT', 'THERE', 'GO', 'GET', 'IT', 'AMERICAN', 'FAMILY', 'TnSuRAnce', 'WELL', 'PROTECT', 'IT', 'AMERICAN', 'FAMILY', 'INSURANCE', 'longlivedreams', 'uinnoue', '6uaacIe', 'Vadsn', 'W', 'Sur_', 'Kecbuenalde', 'o1', 'LlopaDLlplelo', 'LEEEIILLLLLAloll', 'SIILLLL', 'SEELILLzl', 'LEnILLLLL', 'Lo', '4', '3ll5l4LLl', 'Lulull', 'LEEDdill', 'L', 'Lo', '3l55LLLLL', '77']
# without_sonderzeichen: QAAYTE DOLD SAKAT LD EeeI LIV Ja TYI TYI JUL 2MDA20  TYI Iul ZNRAz9 L Compromise scares us too aAAYT Aa WH Aa CIL CD OSL Eenda ANIMAL RESCUE 2501 19 wheels shown delayed availability FPETYARD The allnew Audi A3 The allnew Audi A3_ Designed without compromise OD Prolesslonal diver  Closed course Do not altempt Audi Truth in Engineering StayUncompromised 106 Valet ALL antT Wite Viom BRLTD Logan HILLS CENNEL CLlun DOG show 4M Vittt llon DrOV Logan Hills Cnncl clud Doq show LOo HLLS KENNEL CLUB DOG ShOW WB Smow Flal rolessional stunt Do nol altempL Protessional Stuni De Ws  uecel
# split: ['QAAYTE', 'DOLD', 'SAKAT', 'LD', 'EeeI', 'LIV', 'Ja', 'TYI', 'TYI', 'JUL', '2MDA20', 'TYI', 'Iul', 'ZNRAz9', 'L', 'Compromise', 'scares', 'us', 'too', 'aAAYT', 'Aa', 'WH', 'Aa', 'CIL', 'CD', 'OSL', 'Eenda', 'ANIMAL', 'RESCUE', '2501', '19', 'wheels', 'shown', 'delayed', 'availability', 'FPETYARD', 'The', 'allnew', 'Audi', 'A3', 'The', 'allnew', 'Audi', 'A3_', 'Designed', 'without', 'compromise', 'OD', 'Prolesslonal', 'diver', 'Closed', 'course', 'Do', 'not', 'altempt', 'Audi', 'Truth', 'in', 'Engineering', 'StayUncompromised', '106', 'Valet', 'ALL', 'antT', 'Wite', 'Viom', 'BRLTD', 'Logan', 'HILLS', 'CENNEL', 'CLlun', 'DOG', 'show', '4M', 'Vittt', 'llon', 'DrOV', 'Logan', 'Hills', 'Cnncl', 'clud', 'Doq', 'show', 'LOo', 'HLLS', 'KENNEL', 'CLUB', 'DOG', 'ShOW', 'WB', 'Smow', 'Flal', 'rolessional', 'stunt', 'Do', 'nol', 'altempL', 'Protessional', 'Stuni', 'De', 'Ws', 'uecel']
oR', 'Sale', 'ROCRETT', 'For', 'SALE', 'It', 'ROCREa', 'For', 'SALE', 'RocketFont', '00', 'Homes', 'ROCKET', '19026', '2195', 'chedula', 'Tovt', '52250', 'Mortgage', 'Verified', 'Approval', 'CKET', 'confidence', 'ROC', 'Get', 'backed', 'by', '5', 'with', '_', 'Start', 'Mor', 'andbuy', 'ROCKET', 'ROCKET', 'Homes', 'Mortgage', 'Official', 'Mortgage', 'Provider', 'WFD', 'RaRrieC', 'Masters', 'Oethe', 'Universe', '4uridledu', 'etnt', 'Watle', 'ie', 'o', 'Uneed', 'Wkice', 'Ikeueehom', 'Mallel', '07022', 'Mattel', 'Vallic', 'Aniroaii', 'imnacu', 'On', 'An', 'unkiewiizi', 'cuuehicntee', 'Alah', 'iotr', 'dult', 'icte', 'Muadtcmi', 'Cai', 'Aela', 'Miu', 'deu', 'HiOl', 'puly', 'oasutnilled', 'Ivoxgh', 'nualgeue', 'Cothkuns', 'cy', 'ppl', 'Ritet', 'MoilgJ', 'Anu', 'Raaiei', 'Houe', 'Real', 'UC', 'A', 'ceninte', 'Wriating', 'nkdllaea', 'Rarael', 'Conalct', 'IticNyse', 'RkT', 'Each', 'oimimau', 'LeAAa', 'el', 'ttluy', 'O4el', 'eten', 'f', 'cd', 'fAnaed', 'Ucntigl', 'Oruianajieni', 'rimido', 'Vce', 'a', 'aeeaEmnden', 'eat', 'au', 'Ineraneeale', 'Jcoumallon', 'Aa', 'Dik', 'Aue7u', 'Teunio', 'icuulcuemie', 'RuleiAmtuauc', 'UC', 'NMLS', '31020', 'Votw', 'NMIsConjumatg', 'AlOene', 'Qtu', 'Fuun', 'Houg', 'Lcuet', 'Ukente', 'iq', '50', 'stntes', 'Let', 'No', 'MC', 'Contil', 'No', '100157357', 'Ar', 'Tx', 'i0sq', '4097n', '880', '4740404', '47', 'N', 'Cnt', '2o00', 'Chacn', 'AZ', 'As0n', 'Kongau', 'Aantei', 'Lcmtit', 'ak020zoyo', 'Ca', 'Lk', 'htefr', 'I', 'Drtenti', 'Frt', 'Fnrncia', 'PunecAuu', 'Moilgege', 'ngAc', 'CO', 'RejulaledE', 'Il', 'Dilion', 'o', 'Rei', 'E', 'tal', 'CA', 'RrshentiI', 'MolyJe', '17n4', 'Re', 'denila', 'Matuj', 'Uelge', '04127', 'Depl', 'Fnarc', 'Ial', 'MuilydoCoaly', 'MC', '0n75302', 'MA', 'Moiigu', 'cudce', 'Lecah', '3010', 'Me', 'Scviler', 'cudetieue', 'Nolan', 'ollet', 'tot', 'nicit', 'Ajicoticn', 'MS', 'onncuby', 'UMS', 'NH', 'UauueutwulNhrAntInwu', 'etl', '76743R', 'Nv', 'Lic7le', '7676', 'Ni', 'Na', 'iny', 'Putc', 'Mutgje', 'UC', '1050', 'Wotxinaid', 'Ae', 'Oelrnt', '48276', 'Rar', '74040', 'Uenecu', 'Wetntel', 'anon', 'Ny', 'Rurke', 'MulgJ', 'C', '1o50', 'MRA', 'NAa', 'Deteoll', '48776', 'Keutet', 'Hoilgag', 'RanieNys', 'OWet', 'Faikini', 'SpivcetOk', 'Ha', '850n76', 'Or', 'Ueie', 'Antlrtwi', '14z0', 'Ri', 'ik5umu', 'Lat', 'Cuiemic', 'Uoan', 'Compdx', 'lceleC3020', 'Colc', 'Fitions', 'Mny', 'pply', 'Rru', 'tdt', 'Hone', 'ReAl', 'Estate', 'UIC', 'fully', 'Wpouts', 'Diuen', 'Reai', 'EslateLLC', 'IicZulse', 'iintiets', 'vijil', 'Ror', 'tetHones', 'Vli', '3ueliuini_a', 'Calitc', 'Dre', '301804478', 'Hnlefur', 'Rr23871', 'Woei', 'Ecale', '7077a', '2413', 'ROCKET', '522500', 'Just', 'Listed', 'in', 'Malibu', 'Umagen', 'aimulated', 'Homes', 'Home', 'Better', 'Betteraia', 'Bettyf', 'CASH', 'OFFER', 'CARL', 'CASH', 'CARl', 'House', 'DLPw', 'House', 'ETSPDE', 'SkipPe', 'Imager', 'simulated', 'and', 'sequence', 'chonened', 'tor', 'example', 'purposer', 'only', 'Rate', 'depands', 'on', 'day', 'You', 'lock', 'vout', 'Toid', 'Stockx']
# without_sonderzeichen: s UTTER sutter Toom Jodmn JTeam salesforce Blazen Trail Llloi
# split: ['s', 'UTTER', 'sutter', 'Toom', 'Jodmn', 'JTeam', 'salesforce', 'Blazen', 'Trail', 'Llloi']
# without_sonderzeichen: Omy at Sam  Club Member  Mark sams club 0505 Luotlelo 159525 Etda 0505 Flol cin Un 552525 Ko Hnltaa 1p595 Hioll un 15950 Kot 1p5z5 Flll 5950 MoI Hioillc 1p525 5053 Nt sums club Dairy Mu Id I0 0 to 0 0d od Qu 4d 6d 6EIF VLOTF HiZf VLOIH beef  MIke TGno bief HIC com Oet amit beEF VLOTH VOIH beef bilt HIC DLDIR DuLar 5590 Mancu AOrin betF VUOTH vilI beef bac HLOH beet  Fopw Scan  Go_ Scan  Go Just like Kevin only at sams club SCAN  GO PURCHASED
# split: ['Omy', 'at', 'Sam', 'Club', 'Member', 'Mark', 'sams', 'club', '0505', 'Luotlelo', '159525', 'Etda', '0505', 'Flol', 'cin', 'Un', '552525', 'Ko', 'Hnltaa', '1p595', 'Hioll', 'un', '15950', 'Kot', '1p5z5', 'Flll', '5950', 'MoI', 'Hioillc', '1p525', '5053', 'Nt', 'sums', 'club', 'Dairy', 'Mu', 'Id', 'I0', '0', 'to', '0', '0d', 'od', 'Qu', '4d', '6d', '6EIF', 'VLOTF', 'HiZf', 'VLOIH', 'beef', 'MIke', 'TGno', 'bief', 'HIC', 'com', 'Oet', 'amit', 'beEF', 'VLOTH', 'VOIH', 'beef', 'bilt', 'HIC', 'DLDIR', 'DuLar', '5590', 'Mancu', 'AOrin', 'betF', 'VUOTH', 'vilI', 'beef', 'bac', 'HLOH', 'beet', 'Fopw', 'Scan', 'Go_', 'Scan', 'Go', 'Just', 'like', 'Kevin', 'only', 'at', 'sams', 'club', 'SCAN', 'GO', 'PURCHASED']
# without_sonderzeichen: SLE SIIELLS SALLYS Shop Now SEASHEL Dorow Shop  Shells Qalod Shclls Shop E Shells Liom Spiny Conch _ 67 Great Scallop S Shop S Shells BUXNOW Queen Conch Shells Great Scallop Shells Spiny Conch Shells WILox BUYNOW Pearlf Shells Shells Sop  Shop  Shop  Shopf Frehbing  Conch 5 Shells Shop E Nautilus  Shop C Common  enom Whelk  BUX NOW Su 20 Si 159 see Ao 228 S6c Pcc puc Du SQUARESPACE EVERYTHING TO SHCLL ANYTHING Ug
# split: ['SLE', 'SIIELLS', 'SALLYS', 'Shop', 'Now', 'SEASHEL', 'Dorow', 'Shop', 'Shells', 'Qalod', 'Shclls', 'Shop', 'E', 'Shells', 'Liom', 'Spiny', 'Conch', '_', '67', 'Great', 'Scallop', 'S', 'Shop', 'S', 'Shells', 'BUXNOW', 'Queen', 'Conch', 'Shells', 'Great', 'Scallop', 'Shells', 'Spiny', 'Conch', 'Shells', 'WILox', 'BUYNOW', 'Pearlf', 'Shells', 'Shells', 'Sop', 'Shop', 'Shop', 'Shopf', 'Frehbing', 'Conch', '5', 'Shells', 'Shop', 'E', 'Nautilus', 'Shop', 'C', 'Common', 'enom', 'Whelk', 'BUX', 'NOW', 'Su', '20', 'Si', '159', 'see', 'Ao', '228', 'S6c', 'Pcc', 'puc', 'Du', 'SQUARESPACE', 'EVERYTHING', 'TO', 'SHCLL', 'ANYTHING', 'Ug']
# without_sonderzeichen: CLOWNUSI CLOWNUSI COXFORMUS CONFORMIUS CLOWNUS CONFORMUS Do Not Altempl Do Not Attempt CLOWNUS CLOWNUS Cunfordius cuntornius 6ir Fci FIREL Jaco Bel FIREL Lie Mkc Etf Eco TACO BELL BuRGEAS 02022 Taco Bell IP Hdder LLC
# split: ['CLOWNUSI', 'CLOWNUSI', 'COXFORMUS', 'CONFORMIUS', 'CLOWNUS', 'CONFORMUS', 'Do', 'Not', 'Altempl', 'Do', 'Not', 'Attempt', 'CLOWNUS', 'CLOWNUS', 'Cunfordius', 'cuntornius', '6ir', 'Fci', 'FIREL', 'Jaco', 'Bel', 'FIREL', 'Lie', 'Mkc', 'Etf', 'Eco', 'TACO', 'BELL', 'BuRGEAS', '02022', 'Taco', 'Bell', 'IP', 'Hdder', 'LLC']
# without_sonderzeichen: ton vIJR VERIZON PHONE DESERVES RE 5G BARS IN MORE PLACES TMobile has America 5 largest 5G network See 5G device coverage  access details at T Mobile com ACT NOW CUE YOURATT PHONE TODAY ACT NOW CUE YOUR ATT PHONE TODAY Iru ton VPSG 508  HONES dltsg DoItFortHE PHONCO To be continued_
# split: ['ton', 'vIJR', 'VERIZON', 'PHONE', 'DESERVES', 'RE', '5G', 'BARS', 'IN', 'MORE', 'PLACES', 'TMobile', 'has', 'America', '5', 'largest', '5G', 'network', 'See', '5G', 'device', 'coverage', 'access', 'details', 'at', 'T', 'Mobile', 'com', 'ACT', 'NOW', 'CUE', 'YOURATT', 'PHONE', 'TODAY', 'ACT', 'NOW', 'CUE', 'YOUR', 'ATT', 'PHONE', 'TODAY', 'Iru', 'ton', 'VPSG', '508', 'HONES', 'dltsg', 'DoItFortHE', 'PHONCO', 'To', 'be', 'continued_']
# without_sonderzeichen: INTERMET BILl 558 MtTe2i BlLls 35p elll Terez onal FCC Rate Benchmark SAVE UPTO 50 SGHOMEA INTERNET SAVE UPTO 50 SG HOME INTERNET onal FCC Rate Benchmark INTRODUCING TMOBILE HOME INTERNET 5G HOMES INTERNET CHECKAVAILABILITY  TMOBILECOMWIFI Available t0 many households In most US cities and towns Details at TMobile comWiFi
# split: ['INTERMET', 'BILl', '558', 'MtTe2i', 'BlLls', '35p', 'elll', 'Terez', 'onal', 'FCC', 'Rate', 'Benchmark', 'SAVE', 'UPTO', '50', 'SGHOMEA', 'INTERNET', 'SAVE', 'UPTO', '50', 'SG', 'HOME', 'INTERNET', 'onal', 'FCC', 'Rate', 'Benchmark', 'INTRODUCING', 'TMOBILE', 'HOME', 'INTERNET', '5G', 'HOMES', 'INTERNET', 'CHECKAVAILABILITY', 'TMOBILECOMWIFI', 'Available', 't0', 'many', 'households', 'In', 'most', 'US', 'cities', 'and', 'towns', 'Details', 'at', 'TMobile', 'comWiFi']
# without_sonderzeichen: Cyrus IDa Crka Phones ZA Miley COTRAAU Cyrus IDAEa tha Phones CA Miley 5G PHONES NEED YOUR HELP 30 ITFOR HE PHOt PHO I2 FMobile verizonv NETWORK 5G85Vore SGe8Vre TMobile verizon SGew9c2 sGeawoice verizon TMobile 5632 SGew9ce SCUE YOUR SG PHONE TODAY mnKlejm Jcdsg Il 3 SCUE YOUR 5G PHONE TODAY Based on median overall combined SG speeds according to analysis by Ookla of Speed Iligence data 5G downlond spcads f0r 04 2021 See SG device dovetage  access detilb VOUR 5G PHGNETAD  Ho JTsG Ho JTsG IEAR MORE FROM I HOBI FE DO nT Fe THEF dltsG IEAR MORE FROM MILEY At TMOBILECOM Fok PHONE
# split: ['Cyrus', 'IDa', 'Crka', 'Phones', 'ZA', 'Miley', 'COTRAAU', 'Cyrus', 'IDAEa', 'tha', 'Phones', 'CA', 'Miley', '5G', 'PHONES', 'NEED', 'YOUR', 'HELP', '30', 'ITFOR', 'HE', 'PHOt', 'PHO', 'I2', 'FMobile', 'verizonv', 'NETWORK', '5G85Vore', 'SGe8Vre', 'TMobile', 'verizon', 'SGew9c2', 'sGeawoice', 'verizon', 'TMobile', '5632', 'SGew9ce', 'SCUE', 'YOUR', 'SG', 'PHONE', 'TODAY', 'mnKlejm', 'Jcdsg', 'Il', '3', 'SCUE', 'YOUR', '5G', 'PHONE', 'TODAY', 'Based', 'on', 'median', 'overall', 'combined', 'SG', 'speeds', 'according', 'to', 'analysis', 'by', 'Ookla', 'of', 'Speed', 'Iligence', 'data', '5G', 'downlond', 'spcads', 'f0r', '04', '2021', 'See', 'SG', 'device', 'dovetage', 'access', 'detilb', 'VOUR', '5G', 'PHGNETAD', 'Ho', 'JTsG', 'Ho', 'JTsG', 'IEAR', 'MORE', 'FROM', 'I', 'HOBI', 'FE', 'DO', 'nT', 'Fe', 'THEF', 'dltsG', 'IEAR', 'MORE', 'FROM', 'MILEY', 'At', 'TMOBILECOM', 'Fok', 'PHONE']
# without_sonderzeichen: 4 k ua After Brian lost his eyesight the McKeever brothers went on to win 10 Paralympic medals_ START YOUR IMPOSSIBLE TOYOTA TOYOTA Woidy d v d cymn  Lcac vwine TOYOTA worldwide Worldiide Olympic Partner Paralympie Partncr IOC  GREENSPAN Bud  CTV Tolovision Network Lid Productions Inc AIl rights roserved Cappy
# split: ['4', 'k', 'ua', 'After', 'Brian', 'lost', 'his', 'eyesight', 'the', 'McKeever', 'brothers', 'went', 'on', 'to', 'win', '10', 'Paralympic', 'medals_', 'START', 'YOUR', 'IMPOSSIBLE', 'TOYOTA', 'TOYOTA', 'Woidy', 'd', 'v', 'd', 'cymn', 'Lcac', 'vwine', 'TOYOTA', 'worldwide', 'Worldiide', 'Olympic', 'Partner', 'Paralympie', 'Partncr', 'IOC', 'GREENSPAN', 'Bud', 'CTV', 'Tolovision', 'Network', 'Lid', 'Productions', 'Inc', 'AIl', 'rights', 'roserved', 'Cappy']
# without_sonderzeichen: TRD Pro model available spring 2022 THE ALLNEW TUNDRA EORA TUNDRA TUNDRA TRDCRO MIJONES IJONES Closed course Do not attempt TOYOTA Offroading Is Inherently dangerous Abusive use may in bodily harm or vehicle damage Wear seatbells al all Imes and do not allow passengers In cargo area resull PAsS PROCEED ATc YOUR OWN RISK JONES IJONES
# split: ['TRD', 'Pro', 'model', 'available', 'spring', '2022', 'THE', 'ALLNEW', 'TUNDRA', 'EORA', 'TUNDRA', 'TUNDRA', 'TRDCRO', 'MIJONES', 'IJONES', 'Closed', 'course', 'Do', 'not', 'attempt', 'TOYOTA', 'Offroading', 'Is', 'Inherently', 'dangerous', 'Abusive', 'use', 'may', 'in', 'bodily', 'harm', 'or', 'vehicle', 'damage', 'Wear', 'seatbells', 'al', 'all', 'Imes', 'and', 'do', 'not', 'allow', 'passengers', 'In', 'cargo', 'area', 'resull', 'PAsS', 'PROCEED', 'ATc', 'YOUR', 'OWN', 'RISK', 'JONES', 'IJONES']
# without_sonderzeichen: intult turbotaxLa ERPIRI EHPRL 7o Wi Ta Bada WeRe DOWN To FARTH EMie EMie
# split: ['intult', 'turbotaxLa', 'ERPIRI', 'EHPRL', '7o', 'Wi', 'Ta', 'Bada', 'WeRe', 'DOWN', 'To', 'FARTH', 'EMie', 'EMie']
# without_sonderzeichen: WE CONNECT MORE COUNTRIES THAN ANY OTHER AIRLINE A STAR ALLIANCE Member TURKISH AIRLINES
# split: ['WE', 'CONNECT', 'MORE', 'COUNTRIES', 'THAN', 'ANY', 'OTHER', 'AIRLINE', 'A', 'STAR', 'ALLIANCE', 'Member', 'TURKISH', 'AIRLINES']
# without_sonderzeichen: Uber Eats Foil Aluminum Prop food Do not eatnot food Mt VA Prop food Do not eat anatomy candles Thia SMElLS Lite Uber Candle available in NYC and LAonly onot eat flowers ber food Do noteat sponges Sta8t Iod Uber 95 pod Do not eat paper owels Prol Uber Kitty Litter Prop food Donoteat kitty Hopey Toasted hnclies itter DoO Now delivering Eats Uber Eats PURI Donot actually eat anyof the items shown Item availability varies by market Other restrictions may apply See app for details Od ond Do FOOD ARKLA
# split: ['Uber', 'Eats', 'Foil', 'Aluminum', 'Prop', 'food', 'Do', 'not', 'eatnot', 'food', 'Mt', 'VA', 'Prop', 'food', 'Do', 'not', 'eat', 'anatomy', 'candles', 'Thia', 'SMElLS', 'Lite', 'Uber', 'Candle', 'available', 'in', 'NYC', 'and', 'LAonly', 'onot', 'eat', 'flowers', 'ber', 'food', 'Do', 'noteat', 'sponges', 'Sta8t', 'Iod', 'Uber', '95', 'pod', 'Do', 'not', 'eat', 'paper', 'owels', 'Prol', 'Uber', 'Kitty', 'Litter', 'Prop', 'food', 'Donoteat', 'kitty', 'Hopey', 'Toasted', 'hnclies', 'itter', 'DoO', 'Now', 'delivering', 'Eats', 'Uber', 'Eats', 'PURI', 'Donot', 'actually', 'eat', 'anyof', 'the', 'items', 'shown', 'Item', 'availability', 'varies', 'by', 'market', 'Other', 'restrictions', 'may', 'apply', 'See', 'app', 'for', 'details', 'Od', 'ond', 'Do', 'FOOD', 'ARKLA']
# without_sonderzeichen: verizon 12tia007 Signupat verizon comSG 5G Home and 5G Business Internet available in select areas L9 19 12 2 42 72 5G Home Internet router depieted J0
# split: ['verizon', '12tia007', 'Signupat', 'verizon', 'comSG', '5G', 'Home', 'and', '5G', 'Business', 'Internet', 'available', 'in', 'select', 'areas', 'L9', '19', '12', '2', '42', '72', '5G', 'Home', 'Internet', 'router', 'depieted', 'J0']
# without_sonderzeichen: 3i Go Le ta STop talae Wae Weun STop Wte 4u GoALO 13i ISTop For Stop STOp STOP 4ii 7T Tatl Wg Wue oJ 46h NoJ 40t ic We 7OI Vi STOp ISice STop We Ro3l Di dtadde Iur  Guililueg Aelale Fuiltlins Wtl Gullin STOp e duaehue Forala uaade vroom vroom allonline
# split: ['3i', 'Go', 'Le', 'ta', 'STop', 'talae', 'Wae', 'Weun', 'STop', 'Wte', '4u', 'GoALO', '13i', 'ISTop', 'For', 'Stop', 'STOp', 'STOP', '4ii', '7T', 'Tatl', 'Wg', 'Wue', 'oJ', '46h', 'NoJ', '40t', 'ic', 'We', '7OI', 'Vi', 'STOp', 'ISice', 'STop', 'We', 'Ro3l', 'Di', 'dtadde', 'Iur', 'Guililueg', 'Aelale', 'Fuiltlins', 'Wtl', 'Gullin', 'STOp', 'e', 'duaehue', 'Forala', 'uaade', 'vroom', 'vroom', 'allonline']
# without_sonderzeichen: 202012 Seth T was struck by lightning May Embrace electricity PLuS wallbox 09470420i7 4984d neU_U 0941041044 J9aid
# split: ['202012', 'Seth', 'T', 'was', 'struck', 'by', 'lightning', 'May', 'Embrace', 'electricity', 'PLuS', 'wallbox', '09470420i7', '4984d', 'neU_U', '0941041044', 'J9aid']
# without_sonderzeichen: els WeatherTech WeatherTech WeatherTech On ON n Weai WZ FN Wea om WeatherTeche_com
# split: ['els', 'WeatherTech', 'WeatherTech', 'WeatherTech', 'On', 'ON', 'n', 'Weai', 'WZ', 'FN', 'Wea', 'om', 'WeatherTeche_com']
# Ergebnisse wurden erfolgreich in 'ocr_to_merge.csv' gespeichert.
